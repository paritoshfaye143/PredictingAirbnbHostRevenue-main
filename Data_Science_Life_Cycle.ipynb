# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from scipy import stats as s

# %% [markdown]
# # **1. Exploratory Data Analysis**

# %% [markdown]
# ### Calender

# %% [markdown]
# **Importing calender data**

# %%
cal=pd.read_csv('http://data.insideairbnb.com/united-states/wa/seattle/2022-06-15/data/calendar.csv.gz')
cal.tail()
# Out:
#          listing_id        date available    price adjusted_price  \
# 1953840    33448826  2023-06-10         t  $335.00        $335.00
# 1953841    33448826  2023-06-11         t  $335.00        $335.00
# 1953842    33448826  2023-06-12         t  $335.00        $335.00
# 1953843    33448826  2023-06-13         t  $335.00        $335.00
# 1953844    33448826  2023-06-14         t  $335.00        $335.00
#
#          minimum_nights  maximum_nights
# 1953840               2            1125
# 1953841               2            1125
# 1953842               2            1125
# 1953843               2            1125
# 1953844               2            1125

# %%
cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1953845 entries, 0 to 1953844
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: int64(3), object(4)
# memory usage: 104.3+ MB

# %%
cal.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
#use of slicing and regular expression for removing irrelevant character and special symbol

cal['adjusted_price']=cal['adjusted_price'].astype(str).apply(lambda x:x[1:]).apply(lambda x:re.sub(r',','',x))
cal['adjusted_price']=cal['adjusted_price'].astype(float)

cal['price']=cal['price'].astype(str).apply(lambda x:x[1:]).apply(lambda x:re.sub(r',','',x))
cal['price']=cal['price'].astype(float)

# %% [markdown]
# Correlation between Variables

# %%
cal.corr()
# Out:
#                 listing_id     price  adjusted_price  minimum_nights  \
# listing_id        1.000000  0.079671        0.080059        0.142949
# price             0.079671  1.000000        0.999443        0.000239
# adjusted_price    0.080059  0.999443        1.000000        0.000562
# minimum_nights    0.142949  0.000239        0.000562        1.000000
# maximum_nights   -0.131581 -0.027514       -0.027463        0.153737
#
#                 maximum_nights
# listing_id           -0.131581
# price                -0.027514
# adjusted_price       -0.027463
# minimum_nights        0.153737
# maximum_nights        1.000000

# %% [markdown]
# price and adjusted_price have strong positive correlation.

# %%
cal['available']=cal['available'].apply(lambda x: 1 if x=='t' else 0)

# %%
cal.head()
# Out:
#            listing_id        date  available  price  adjusted_price  \
# 0  580365544480383496  2022-06-15          0  108.0           108.0
# 1  580365544480383496  2022-06-16          0  177.0           177.0
# 2  580365544480383496  2022-06-17          0  193.0           193.0
# 3  580365544480383496  2022-06-18          0  193.0           193.0
# 4  580365544480383496  2022-06-19          0  193.0           193.0
#
#    minimum_nights  maximum_nights
# 0               2            1125
# 1               2            1125
# 2               2            1125
# 3               2            1125
# 4               2            1125

# %% [markdown]
# Descriptive Statistics

# %%
cal.describe()
# Out:
#          listing_id     available         price  adjusted_price  \
# count  1.953845e+06  1.953845e+06  1.953845e+06    1.953845e+06
# mean   8.581482e+16  4.692378e-01  2.012934e+02    2.010600e+02
# std    2.095459e+17  4.990529e-01  1.702995e+02    1.701860e+02
# min    6.606000e+03  0.000000e+00  1.000000e+01    1.000000e+01
# 25%    2.098306e+07  0.000000e+00  1.080000e+02    1.080000e+02
# 50%    4.267289e+07  0.000000e+00  1.590000e+02    1.590000e+02
# 75%    5.233190e+07  1.000000e+00  2.470000e+02    2.460000e+02
# max    6.484045e+17  1.000000e+00  6.035000e+03    6.035000e+03
#
#        minimum_nights  maximum_nights
# count    1.953845e+06    1.953845e+06
# mean     5.217751e+01    8.215125e+02
# std      1.652444e+02    4.711195e+02
# min      1.000000e+00    1.000000e+00
# 25%      2.000000e+00    3.650000e+02
# 50%      3.000000e+00    1.125000e+03
# 75%      3.000000e+01    1.125000e+03
# max      7.300000e+02    1.000000e+04

# %% [markdown]
# Here mean is greater than median hence the calender data is positively skewed

# %%
cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1953845 entries, 0 to 1953844
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       int64
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 104.3+ MB

# %% [markdown]
# **date vs price**

# %%
sns.lineplot(data=cal, x="date", y="price")
plt.xlabel('date')
plt.ylabel('price')
plt.title('Date vs Price')
plt.show()

# %% [markdown]
# Graph shows some seasonal trend which can be clearly seen by monthwise price

# %% [markdown]
# **Monthwise price**

# %%
def getMMYYYY(x):
    d=x.split('-')
    return d[1]+'/'+d[0]
cal['mm-yyyy']=cal['date'].apply(lambda x:getMMYYYY(x))

# %%
#price and adjusted price have strong positive correlation, so price is choosen
sns.lineplot(data=cal, x="mm-yyyy", y="price")
plt.xticks(rotation=90)
plt.xlabel('month')
plt.ylabel('price')
plt.title('Monthwise Price')
plt.show()

# %% [markdown]
# Pattern observed from 06/2022 to 12/2022 may repeat next year as inferred from graph

# %% [markdown]
# The best time to visit Seattle is from June to early October. Summer marks the city's high season, meaning room rates rise and availability drops, while cold winter weather can deter even the most avid sightseers. After January winter ends and beginning of Spring marks the rising rates of AirBnb.

# %% [markdown]
# **Monthwise availability**

# %%
sns.lineplot(data=cal, x="mm-yyyy", y="available")
plt.xticks(rotation=90)
plt.xlabel('month')
plt.ylabel('available')
plt.title('Monthwise availability')
plt.show()

# %% [markdown]
# Summer marks the city's high season, meaning room rates rise and availability drops, from June to November. While cold winter weather starts tourists descrease and rooms availability increases.

# %% [markdown]
# **Weekday graph**

# %%
from pandas.api.types import CategoricalDtype

cal['date'] = pd.to_datetime(cal['date'])

cal['day_of_week'] = cal['date'].dt.day_name()
cats = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
cat_type = CategoricalDtype(categories=cats, ordered=True)
cal['day_of_week'] = cal['day_of_week'].astype(cat_type)
week=cal.groupby('day_of_week').price.mean().reset_index().rename(columns={'price':'average_price'})

plt.figure(figsize=(10,7))
plt.plot(week['day_of_week'],week['average_price'],marker='o')
plt.xticks(rotation=90)
plt.xlabel('day_of_week')
plt.ylabel('Average Price')
plt.title('Day of week vs Average price')
plt.show()

# %% [markdown]
# **Price distribution**

# %%
plt.figure(figsize=(20,7))
sns.histplot(data=cal, x="price",bins=500,kde=True)
plt.xlim(0,cal['price'].max()+10 )  #why is +10??? 
plt.axvline(np.median(cal['price']),color='b', linestyle='--')
plt.title('Price distribution')
plt.show()

# %% [markdown]
# Price distribution has positively skewed distribution. Most of the people prefer rooms with lower prices.

# %% [markdown]
# **Frequently booked price of room**

# %%
s.mode(cal['price'])
# Out:
# <ipython-input-18-1ac2207a0326>:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   s.mode(cal['price'])
# ModeResult(mode=array([150.]), count=array([37063]))

# %% [markdown]
# Rooms with price $150 are booked most frequently.

# %% [markdown]
# ### Listings

# %% [markdown]
# **Importing listings data**

# %%
listings_link='http://data.insideairbnb.com/united-states/wa/seattle/2022-06-15/data/listings.csv.gz'
lst = pd.read_csv(listings_link)

# %%
lst.tail()
# Out:
#                       id                                      listing_url  \
# 5350            16733665            https://www.airbnb.com/rooms/16733665
# 5351            25846790            https://www.airbnb.com/rooms/25846790
# 5352            49692446            https://www.airbnb.com/rooms/49692446
# 5353  587785014993543336  https://www.airbnb.com/rooms/587785014993543336
# 5354            53475139            https://www.airbnb.com/rooms/53475139
#
#            scrape_id last_scraped                                      name  \
# 5350  20220615002636   2022-06-15  Quiet 2BR Townhouse in Bustling Eastlake
# 5351  20220615002636   2022-06-15            Peaceful Home! Great Location!
# 5352  20220615002636   2022-06-15                       Home away from home
# 5353  20220615002636   2022-06-15                 Kirkland placid community
# 5354  20220615002636   2022-06-15         Alki Beach 1-Bedroom Cozy Retreat
#
#                                             description  \
# 5350  This is a two bedroom, three bathroom townhous...
# 5351  Amazing location! <br />The house has charm. M...
# 5352  Walking distance from Starbucks, parks around,...
# 5353  Have a Relax And quiet stay at this comfortabl...
# 5354  Charming waterside Alki Beach condo located ju...
#
#                                   neighborhood_overview  \
# 5350  Eastlake is a fun neighborhood with something ...
# 5351  Great location!  Easily accessible to frwy exi...
# 5352  Parking right in front of home, close to parks...
# 5353  o o denny park<br />Juanita Woodlands Park<br ...
# 5354                                                NaN
#
#                                             picture_url    host_id  \
# 5350  https://a0.muscache.com/pictures/620b8144-c90e...   36390224
# 5351  https://a0.muscache.com/pictures/c08af974-484f...    3903741
# 5352  https://a0.muscache.com/pictures/665e7eca-cfbc...  268690467
# 5353  https://a0.muscache.com/pictures/db9da635-18a0...  448872479
# 5354  https://a0.muscache.com/pictures/80a21d8e-5469...  433024286
#
#                                          host_url  ...  \
# 5350   https://www.airbnb.com/users/show/36390224  ...
# 5351    https://www.airbnb.com/users/show/3903741  ...
# 5352  https://www.airbnb.com/users/show/268690467  ...
# 5353  https://www.airbnb.com/users/show/448872479  ...
# 5354  https://www.airbnb.com/users/show/433024286  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 5350                        5.00                   4.90                4.87
# 5351                        5.00                   4.73                4.67
# 5352                        5.00                   4.00                4.33
# 5353                        4.93                   4.71                4.79
# 5354                        5.00                   5.00                4.50
#
#                  license instant_bookable calculated_host_listings_count  \
# 5350  STR-OPLI-19-002743                f                              1
# 5351                 NaN                f                              1
# 5352                 NaN                t                              1
# 5353                 NaN                t                              1
# 5354                 NaN                t                              1
#
#      calculated_host_listings_count_entire_homes  \
# 5350                                           1
# 5351                                           1
# 5352                                           1
# 5353                                           1
# 5354                                           1
#
#      calculated_host_listings_count_private_rooms  \
# 5350                                            0
# 5351                                            0
# 5352                                            0
# 5353                                            0
# 5354                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 5350                                           0              0.48
# 5351                                           0              0.31
# 5352                                           0              0.28
# 5353                                           0              5.49
# 5354                                           0              1.02
#
# [5 rows x 74 columns]

# %%
lst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5355 entries, 0 to 5354
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5355 non-null   int64
#  1   listing_url                                   5355 non-null   object
#  2   scrape_id                                     5355 non-null   int64
#  3   last_scraped                                  5355 non-null   object
#  4   name                                          5355 non-null   object
#  5   description                                   5348 non-null   object
#  6   neighborhood_overview                         4000 non-null   object
#  7   picture_url                                   5355 non-null   object
#  8   host_id                                       5355 non-null   int64
#  9   host_url                                      5355 non-null   object
#  10  host_name                                     5355 non-null   object
#  11  host_since                                    5355 non-null   object
#  12  host_location                                 5351 non-null   object
#  13  host_about                                    3871 non-null   object
#  14  host_response_time                            4862 non-null   object
#  15  host_response_rate                            4862 non-null   object
#  16  host_acceptance_rate                          5009 non-null   object
#  17  host_is_superhost                             5355 non-null   object
#  18  host_thumbnail_url                            5355 non-null   object
#  19  host_picture_url                              5355 non-null   object
#  20  host_neighbourhood                            4875 non-null   object
#  21  host_listings_count                           5355 non-null   int64
#  22  host_total_listings_count                     5355 non-null   int64
#  23  host_verifications                            5355 non-null   object
#  24  host_has_profile_pic                          5355 non-null   object
#  25  host_identity_verified                        5355 non-null   object
#  26  neighbourhood                                 4000 non-null   object
#  27  neighbourhood_cleansed                        5355 non-null   object
#  28  neighbourhood_group_cleansed                  5355 non-null   object
#  29  latitude                                      5355 non-null   float64
#  30  longitude                                     5355 non-null   float64
#  31  property_type                                 5355 non-null   object
#  32  room_type                                     5355 non-null   object
#  33  accommodates                                  5355 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                5352 non-null   object
#  36  bedrooms                                      4716 non-null   float64
#  37  beds                                          5269 non-null   float64
#  38  amenities                                     5355 non-null   object
#  39  price                                         5355 non-null   object
#  40  minimum_nights                                5355 non-null   int64
#  41  maximum_nights                                5355 non-null   int64
#  42  minimum_minimum_nights                        5353 non-null   float64
#  43  maximum_minimum_nights                        5353 non-null   float64
#  44  minimum_maximum_nights                        5353 non-null   float64
#  45  maximum_maximum_nights                        5353 non-null   float64
#  46  minimum_nights_avg_ntm                        5353 non-null   float64
#  47  maximum_nights_avg_ntm                        5353 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              5355 non-null   object
#  50  availability_30                               5355 non-null   int64
#  51  availability_60                               5355 non-null   int64
#  52  availability_90                               5355 non-null   int64
#  53  availability_365                              5355 non-null   int64
#  54  calendar_last_scraped                         5355 non-null   object
#  55  number_of_reviews                             5355 non-null   int64
#  56  number_of_reviews_ltm                         5355 non-null   int64
#  57  number_of_reviews_l30d                        5355 non-null   int64
#  58  first_review                                  4613 non-null   object
#  59  last_review                                   4613 non-null   object
#  60  review_scores_rating                          4613 non-null   float64
#  61  review_scores_accuracy                        4606 non-null   float64
#  62  review_scores_cleanliness                     4606 non-null   float64
#  63  review_scores_checkin                         4606 non-null   float64
#  64  review_scores_communication                   4606 non-null   float64
#  65  review_scores_location                        4606 non-null   float64
#  66  review_scores_value                           4606 non-null   float64
#  67  license                                       3933 non-null   object
#  68  instant_bookable                              5355 non-null   object
#  69  calculated_host_listings_count                5355 non-null   int64
#  70  calculated_host_listings_count_entire_homes   5355 non-null   int64
#  71  calculated_host_listings_count_private_rooms  5355 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   5355 non-null   int64
#  73  reviews_per_month                             4613 non-null   float64
# dtypes: float64(20), int64(19), object(35)
# memory usage: 3.0+ MB

# %% [markdown]
# Removing space and character

# %%
lst['price']=lst['price'].astype(str).apply(lambda x:x[1:]).apply(lambda x:re.sub(r',','',x))
lst['price']=lst['price'].astype(float)

# %% [markdown]
# **Top 5 host locations**

# %%
if listings_link.split('/')[5]=='seattle':
  lst.loc[lst['host_location']=='  and Seattle Washington and Montezuma,Costa Rica','host_location']='Seattle Washington and Montezuma,Costa Rica'

host_loc_group = lst['host_location'].value_counts().sort_values(ascending=False)[:5].reset_index().rename(columns={'index':'host_location','host_location':'count'})

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sns.barplot(x='host_location', y='count', data=host_loc_group, ax=ax)
ax.bar_label(ax.containers[-1], fmt='Count:\n%.2f', label_type='edge')
ax.set(ylabel='count')
plt.xticks(rotation=45)
plt.title('Top 5 host locations based on number of listings')
plt.show()

# %% [markdown]
# Maximum hosts are from Seattle, Washington.

# %% [markdown]
# **Host response time frequencies**

# %%
lst['host_response_time'].value_counts(dropna=False)
# Out:
# within an hour        4044
# within a few hours     523
# NaN                    493
# within a day           237
# a few days or more      58
# Name: host_response_time, dtype: int64

# %%
##selecting and replacing NaN values with 'Not available'
   
lst['host_response_time'].fillna('Not available',inplace=True)

# %%
lst['host_response_time'].value_counts(dropna=False)
# Out:
# within an hour        4044
# within a few hours     523
# Not available          493
# within a day           237
# a few days or more      58
# Name: host_response_time, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sns.countplot(x=lst["host_response_time"])
ax.bar_label(ax.containers[-1], fmt='Count:\n%.2f', label_type='edge')
ax.set(ylabel='count')
plt.xticks(rotation=45)
plt.title('Host response time')
plt.show()

# %% [markdown]
# Most reponses are served within an hour.

# %% [markdown]
# **Top 5 Host response rates**

# %%
lst.loc[lst['host_response_rate'].isnull(),'host_response_rate']='unknown'

top_5_res_rate = lst['host_response_rate'].value_counts().sort_values(ascending=False)[:5].reset_index().rename(columns={'index':'reponse_rate','host_response_rate':'count'})
top_5_res_rate
# Out:
#   reponse_rate  count
# 0         100%   3910
# 1      unknown    493
# 2          99%    227
# 3          97%    114
# 4          90%    109

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sns.barplot(x='reponse_rate', y='count', data=top_5_res_rate, ax=ax)
ax.bar_label(ax.containers[-1], fmt='Count:\n%.2f', label_type='edge')
ax.set(ylabel='count')
plt.title('Response rates')
plt.show()

# %% [markdown]
# Most of the hosts respond almost to every user for booking requests.

# %% [markdown]
# **Top 5 Host acceptance rates**

# %%
lst['host_acceptance_rate'].unique()
# Out:
# array(['92%', '0%', '64%', '88%', '93%', '70%', '100%', '60%', '50%',
#        '73%', '98%', nan, '99%', '90%', '95%', '87%', '17%', '94%', '58%',
#        '71%', '56%', '80%', '91%', '97%', '33%', '89%', '20%', '96%',
#        '67%', '24%', '85%', '78%', '57%', '75%', '14%', '77%', '81%',
#        '79%', '86%', '25%', '62%', '76%', '39%', '69%', '68%', '47%',
#        '83%', '63%', '84%', '52%', '55%', '74%', '82%', '61%', '40%',
#        '6%', '54%', '53%', '72%', '5%', '66%', '46%', '43%', '3%', '41%',
#        '65%', '10%', '35%'], dtype=object)

# %%
#Replacing NaN with Not available
lst.loc[lst['host_acceptance_rate'].isnull(),'host_acceptance_rate']='Not available'
lst[lst['host_acceptance_rate'].isnull()]['id'].count()

top_5_acc_rate = lst['host_acceptance_rate'].value_counts().sort_values(ascending=False)[:5].reset_index().rename(columns={'index':'acceptance_rate','host_acceptance_rate':'count'})
top_5_acc_rate
# Out:
#   acceptance_rate  count
# 0            100%   2120
# 1             98%    701
# 2             99%    500
# 3   Not available    346
# 4             97%    193

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sns.barplot(x='acceptance_rate', y='count', data=top_5_acc_rate, ax=ax)
ax.bar_label(ax.containers[-1], fmt='Count:\n%.2f', label_type='edge')
ax.set(ylabel='count')
plt.title('Top 5 Host acceptance rates')
plt.show()

# %% [markdown]
# Most hosts accept every user request.

# %% [markdown]
# **Superhost**

# %%
lst['host_is_superhost'].value_counts(normalize=True)*100
# Out:
# f    59.589169
# t    40.410831
# Name: host_is_superhost, dtype: float64

# %% [markdown]
# Almost 40% hosts are superhosts.

# %%
fig, ax = plt.subplots(figsize=(8, 8))

sns.countplot(data=lst,x='host_is_superhost')
ax.bar_label(ax.containers[-1], fmt='Count:\n%.2f', label_type='edge')
plt.title('Superhost')
plt.show()

# %% [markdown]
# 2164 i.e 40% hosts are superhosts.

# %% [markdown]
# Every 3 months, each host is evaluated on their hospitality.
# Superhosts should meet all of the criteria
# - 4.8+ overall rating
# - 10+ stays
# - <1% cancellation rate
# - 90% response rate

# %% [markdown]
# **Top 5 host neighbourhoods**

# %%
top_5_host_neighbourhood=lst['host_neighbourhood'].value_counts(ascending=False)[:5].reset_index().rename(columns={'index':'host_neighbourhood','host_neighbourhood':'count'})
top_5_host_neighbourhood
# Out:
#   host_neighbourhood  count
# 0       Capitol Hill    357
# 1          Cambridge    308
# 2              Minor    235
# 3       West Seattle    204
# 4        Wallingford    192

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sns.barplot(x='host_neighbourhood', y='count', data=top_5_host_neighbourhood, ax=ax)
ax.bar_label(ax.containers[-1], fmt='Count:\n%.2f', label_type='edge')
ax.set(ylabel='count')
plt.title('Top 5 host neighbourhoods')
plt.show()

# %% [markdown]
# Capitol Hill, Cambridge, Minor, West Seattle and Wallingford are top neighborhoods around which hosts are located.

# %% [markdown]
# **Host verifications**

# %%
lst['host_verifications'].value_counts(normalize=True)*100
# Out:
# ['email', 'phone']                  73.202614
# ['email', 'phone', 'work_email']    21.942110
# ['phone']                            4.481793
# ['phone', 'work_email']              0.242764
# ['email']                            0.130719
# Name: host_verifications, dtype: float64

# %% [markdown]
# 73% verifications are done through email or phone.

# %% [markdown]
# **Host identity verified**

# %%
lst['host_identity_verified'].value_counts(normalize=True)*100
# Out:
# t    87.077498
# f    12.922502
# Name: host_identity_verified, dtype: float64

# %%
host_identity = lst['host_identity_verified'].value_counts(normalize=True)*100

# %%
plt.pie(host_identity, labels=host_identity.index,
   autopct=lambda p: '{:.0f}%'.format(p * sum(host_identity) / 100),
   shadow=True, startangle=90)

plt.show()

# %% [markdown]
# Almost 87% hosts have verified their identity.

# %% [markdown]
# **Top 10 Property types offerred by hosts**

# %%
lst['property_type'].value_counts()[:10]
# Out:
# Entire rental unit           1263
# Entire home                  1133
# Entire guest suite            672
# Entire condo                  497
# Private room in home          490
# Entire townhouse              385
# Entire guesthouse             219
# Entire serviced apartment     175
# Private room in townhouse      94
# Room in boutique hotel         68
# Name: property_type, dtype: int64

# %% [markdown]
# **room types**

# %%
lst['room_type'].value_counts(normalize=True)*100
# Out:
# Entire home/apt    84.369748
# Private room       14.920635
# Shared room         0.672269
# Hotel room          0.037348
# Name: room_type, dtype: float64

# %% [markdown]
# Almost 84% offerings are of Entire home/apt.

# %% [markdown]
# **bedroom vs bed**

# %%
sns.scatterplot(x='beds',y='bedrooms',data=lst)
plt.xlabel('beds')
plt.ylabel('bedrooms')
plt.title('Bedroom vs Bed')
plt.show()

# %%
lst[['beds','bedrooms']].corr()
# Out:
#              beds  bedrooms
# beds      1.00000   0.84788
# bedrooms  0.84788   1.00000

# %% [markdown]
# beds and bedroom are strongly positively correlated.

# %% [markdown]
# **Average Price per Host location**

# %%
per_host=pd.DataFrame(index=lst.groupby('host_location')['price'].count().sort_index().index)
per_host['avg_price']=lst.groupby('host_location')['price'].mean().sort_index()
per_host['count']=lst.groupby('host_location')['price'].count().sort_index()

per_host = per_host.sort_values('count',ascending=False)[:5].reset_index()
per_host
# Out:
#                               host_location   avg_price  count
# 0        Seattle, Washington, United States  183.609644   3484
# 1                                        US  223.842956    433
# 2         New York, New York, United States  176.134048    373
# 3  San Francisco, California, United States  219.603306    121
# 4       Bellevue, Washington, United States  263.669492    118

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sns.barplot(x='host_location', y='avg_price', data=per_host, ax=ax)
ax.bar_label(ax.containers[-1], fmt='\n%.2f', label_type='edge')
ax.set(ylabel='average price')
plt.xticks(rotation=45)
plt.title('Average Price per Host location')
plt.show()

# %% [markdown]
# **Price by ratings**

# %%
price_by_rating = lst[~lst['review_scores_rating'].isnull()][['review_scores_rating','price']]

plt.figure(figsize=(20,7))
sns.histplot(data=price_by_rating, x="review_scores_rating",bins=30,kde=True)
plt.title('Price by ratings')
plt.show()

# %%
price_by_rating['review_scores_rating'].value_counts().sort_values(ascending=False)
# Out:
# 5.00    961
# 4.96    159
# 4.94    142
# 4.92    140
# 4.93    131
#        ...
# 3.57      1
# 3.88      1
# 3.87      1
# 3.14      1
# 4.26      1
# Name: review_scores_rating, Length: 125, dtype: int64

# %% [markdown]
# Top rating provided is 5 for almost 961 hosts.

# %% [markdown]
# **Reviews**

# %%
reviews = lst.filter(regex=r'^review',axis=1)
reviews['price']=lst.price

plt.figure(figsize=(15,12))
sns.heatmap(reviews.corr(),annot=True,cmap="YlGnBu",annot_kws={'size': 15},cbar=True)
plt.show()
# Out:
# <ipython-input-49-3d3d0a17d281>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['price']=lst.price

# %% [markdown]
# review_score_rating have positive correlation with review_scores_accuracy and review_scores_value

# %% [markdown]
# # **2. Data Preprocessing**

# %% [markdown]
# ## Import Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as s

# %% [markdown]
# ## Import Data

# %%
calendar_df=pd.read_csv('http://data.insideairbnb.com/united-states/wa/seattle/2022-06-15/data/calendar.csv.gz')
listings_link='http://data.insideairbnb.com/united-states/wa/seattle/2022-06-15/data/listings.csv.gz'
listings_df = pd.read_csv(listings_link)

# %% [markdown]
# ## Data Transformation

# %%
#Removing Irrelavent Spaces and Character
listings_df['price'] = listings_df['price'].map(lambda x: x.lstrip("$").replace(",", "")).astype(float)
calendar_df['price'] = calendar_df['price'].astype(str).map(lambda x: x.lstrip("$").replace(",", "")).astype(float)

# %%
calendar_df['available'] = calendar_df['available'].map({'t':1, 'f':0})
calendar_df['revenue'] = calendar_df['price']*calendar_df['available']

# %%
calendar_df = calendar_df.fillna(0)
overview = calendar_df.groupby('listing_id').mean()
overview['daily_revenue'] = overview['revenue']
overview['booking_rate(%)'] = overview['available']*100

# %%
overview
# Out:
#                     available       price  minimum_nights  maximum_nights  \
# listing_id
# 6606                 0.230137  106.704110       30.000000     1125.000000
# 9419                 0.906849   80.723288        2.000000      180.000000
# 9531                 0.591781  179.230137        4.868493     1091.684932
# 9534                 0.687671  125.876712        3.000000     1125.000000
# 9596                 0.101370  130.000000       30.000000      200.000000
# ...                       ...         ...             ...             ...
# 646276083976193412   0.194521  294.852055        1.890411       12.000000
# 646302173365139407   0.189041  480.128767        1.315068       12.000000
# 646321998874157520   0.824658  290.871233        1.000000     1125.000000
# 646366857822301601   0.443836  175.000000       30.000000      120.000000
# 648404465900993561   0.950685  232.208219       30.000000     1125.000000
#
#                        revenue  daily_revenue  booking_rate(%)
# listing_id
# 6606                 23.035616      23.035616        23.013699
# 9419                 73.068493      73.068493        90.684932
# 9531                104.301370     104.301370        59.178082
# 9534                 86.013699      86.013699        68.767123
# 9596                 13.178082      13.178082        10.136986
# ...                        ...            ...              ...
# 646276083976193412   62.676712      62.676712        19.452055
# 646302173365139407  100.230137     100.230137        18.904110
# 646321998874157520  226.098630     226.098630        82.465753
# 646366857822301601   77.671233      77.671233        44.383562
# 648404465900993561  220.309589     220.309589        95.068493
#
# [5353 rows x 7 columns]

# %%
calendar_booked = calendar_df[calendar_df['price']!=0]
calendar_booked = calendar_booked.groupby('listing_id').agg({'price':['mean','std']}).reset_index()
calendar_booked.columns=['listing_id','price_avg','price_std']

# %%
cleaned_df = listings_df.drop('price', axis=1)
overview = overview[['available', 'price', 'revenue',
      'daily_revenue', 'booking_rate(%)']]
cleaned_df = pd.merge(cleaned_df, overview, how='left', left_on='id', right_on='listing_id')
cleaned_df = pd.merge(cleaned_df, calendar_booked, how='left', left_on='id', right_on='listing_id')
cleaned_df['price_per_person'] = cleaned_df['price'] / listings_df['accommodates']
cleaned_df = cleaned_df.drop(['listing_id'], axis=1)

# %%
cleaned_df.isnull().sum()
# Out:
# id                  0
# listing_url         0
# scrape_id           0
# last_scraped        0
# name                0
#                    ..
# daily_revenue       2
# booking_rate(%)     2
# price_avg           2
# price_std           2
# price_per_person    2
# Length: 81, dtype: int64

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5355 entries, 0 to 5354
# Data columns (total 81 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5355 non-null   int64
#  1   listing_url                                   5355 non-null   object
#  2   scrape_id                                     5355 non-null   int64
#  3   last_scraped                                  5355 non-null   object
#  4   name                                          5355 non-null   object
#  5   description                                   5348 non-null   object
#  6   neighborhood_overview                         4000 non-null   object
#  7   picture_url                                   5355 non-null   object
#  8   host_id                                       5355 non-null   int64
#  9   host_url                                      5355 non-null   object
#  10  host_name                                     5355 non-null   object
#  11  host_since                                    5355 non-null   object
#  12  host_location                                 5351 non-null   object
#  13  host_about                                    3871 non-null   object
#  14  host_response_time                            4862 non-null   object
#  15  host_response_rate                            4862 non-null   object
#  16  host_acceptance_rate                          5009 non-null   object
#  17  host_is_superhost                             5355 non-null   object
#  18  host_thumbnail_url                            5355 non-null   object
#  19  host_picture_url                              5355 non-null   object
#  20  host_neighbourhood                            4875 non-null   object
#  21  host_listings_count                           5355 non-null   int64
#  22  host_total_listings_count                     5355 non-null   int64
#  23  host_verifications                            5355 non-null   object
#  24  host_has_profile_pic                          5355 non-null   object
#  25  host_identity_verified                        5355 non-null   object
#  26  neighbourhood                                 4000 non-null   object
#  27  neighbourhood_cleansed                        5355 non-null   object
#  28  neighbourhood_group_cleansed                  5355 non-null   object
#  29  latitude                                      5355 non-null   float64
#  30  longitude                                     5355 non-null   float64
#  31  property_type                                 5355 non-null   object
#  32  room_type                                     5355 non-null   object
#  33  accommodates                                  5355 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                5352 non-null   object
#  36  bedrooms                                      4716 non-null   float64
#  37  beds                                          5269 non-null   float64
#  38  amenities                                     5355 non-null   object
#  39  minimum_nights                                5355 non-null   int64
#  40  maximum_nights                                5355 non-null   int64
#  41  minimum_minimum_nights                        5353 non-null   float64
#  42  maximum_minimum_nights                        5353 non-null   float64
#  43  minimum_maximum_nights                        5353 non-null   float64
#  44  maximum_maximum_nights                        5353 non-null   float64
#  45  minimum_nights_avg_ntm                        5353 non-null   float64
#  46  maximum_nights_avg_ntm                        5353 non-null   float64
#  47  calendar_updated                              0 non-null      float64
#  48  has_availability                              5355 non-null   object
#  49  availability_30                               5355 non-null   int64
#  50  availability_60                               5355 non-null   int64
#  51  availability_90                               5355 non-null   int64
#  52  availability_365                              5355 non-null   int64
#  53  calendar_last_scraped                         5355 non-null   object
#  54  number_of_reviews                             5355 non-null   int64
#  55  number_of_reviews_ltm                         5355 non-null   int64
#  56  number_of_reviews_l30d                        5355 non-null   int64
#  57  first_review                                  4613 non-null   object
#  58  last_review                                   4613 non-null   object
#  59  review_scores_rating                          4613 non-null   float64
#  60  review_scores_accuracy                        4606 non-null   float64
#  61  review_scores_cleanliness                     4606 non-null   float64
#  62  review_scores_checkin                         4606 non-null   float64
#  63  review_scores_communication                   4606 non-null   float64
#  64  review_scores_location                        4606 non-null   float64
#  65  review_scores_value                           4606 non-null   float64
#  66  license                                       3933 non-null   object
#  67  instant_bookable                              5355 non-null   object
#  68  calculated_host_listings_count                5355 non-null   int64
#  69  calculated_host_listings_count_entire_homes   5355 non-null   int64
#  70  calculated_host_listings_count_private_rooms  5355 non-null   int64
#  71  calculated_host_listings_count_shared_rooms   5355 non-null   int64
#  72  reviews_per_month                             4613 non-null   float64
#  73  available                                     5353 non-null   float64
#  74  price                                         5353 non-null   float64
#  75  revenue                                       5353 non-null   float64
#  76  daily_revenue                                 5353 non-null   float64
#  77  booking_rate(%)                               5353 non-null   float64
#  78  price_avg                                     5353 non-null   float64
#  79  price_std                                     5353 non-null   float64
#  80  price_per_person                              5353 non-null   float64
# dtypes: float64(28), int64(19), object(34)
# memory usage: 3.4+ MB

# %% [markdown]
# ## Knowledge-based features

# %%
cleaned_df['accom_per_bed'] = cleaned_df['accommodates']/cleaned_df['beds']
cleaned_df['price_surge_percent'] = (cleaned_df['price_avg']/cleaned_df['price']-1)*100

#To check abrupt changes in price during peak season
cleaned_df['price_std_percent'] = cleaned_df['price_std']/cleaned_df['price']*100

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5355 entries, 0 to 5354
# Data columns (total 84 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5355 non-null   int64
#  1   listing_url                                   5355 non-null   object
#  2   scrape_id                                     5355 non-null   int64
#  3   last_scraped                                  5355 non-null   object
#  4   name                                          5355 non-null   object
#  5   description                                   5348 non-null   object
#  6   neighborhood_overview                         4000 non-null   object
#  7   picture_url                                   5355 non-null   object
#  8   host_id                                       5355 non-null   int64
#  9   host_url                                      5355 non-null   object
#  10  host_name                                     5355 non-null   object
#  11  host_since                                    5355 non-null   object
#  12  host_location                                 5351 non-null   object
#  13  host_about                                    3871 non-null   object
#  14  host_response_time                            4862 non-null   object
#  15  host_response_rate                            4862 non-null   object
#  16  host_acceptance_rate                          5009 non-null   object
#  17  host_is_superhost                             5355 non-null   object
#  18  host_thumbnail_url                            5355 non-null   object
#  19  host_picture_url                              5355 non-null   object
#  20  host_neighbourhood                            4875 non-null   object
#  21  host_listings_count                           5355 non-null   int64
#  22  host_total_listings_count                     5355 non-null   int64
#  23  host_verifications                            5355 non-null   object
#  24  host_has_profile_pic                          5355 non-null   object
#  25  host_identity_verified                        5355 non-null   object
#  26  neighbourhood                                 4000 non-null   object
#  27  neighbourhood_cleansed                        5355 non-null   object
#  28  neighbourhood_group_cleansed                  5355 non-null   object
#  29  latitude                                      5355 non-null   float64
#  30  longitude                                     5355 non-null   float64
#  31  property_type                                 5355 non-null   object
#  32  room_type                                     5355 non-null   object
#  33  accommodates                                  5355 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                5352 non-null   object
#  36  bedrooms                                      4716 non-null   float64
#  37  beds                                          5269 non-null   float64
#  38  amenities                                     5355 non-null   object
#  39  minimum_nights                                5355 non-null   int64
#  40  maximum_nights                                5355 non-null   int64
#  41  minimum_minimum_nights                        5353 non-null   float64
#  42  maximum_minimum_nights                        5353 non-null   float64
#  43  minimum_maximum_nights                        5353 non-null   float64
#  44  maximum_maximum_nights                        5353 non-null   float64
#  45  minimum_nights_avg_ntm                        5353 non-null   float64
#  46  maximum_nights_avg_ntm                        5353 non-null   float64
#  47  calendar_updated                              0 non-null      float64
#  48  has_availability                              5355 non-null   object
#  49  availability_30                               5355 non-null   int64
#  50  availability_60                               5355 non-null   int64
#  51  availability_90                               5355 non-null   int64
#  52  availability_365                              5355 non-null   int64
#  53  calendar_last_scraped                         5355 non-null   object
#  54  number_of_reviews                             5355 non-null   int64
#  55  number_of_reviews_ltm                         5355 non-null   int64
#  56  number_of_reviews_l30d                        5355 non-null   int64
#  57  first_review                                  4613 non-null   object
#  58  last_review                                   4613 non-null   object
#  59  review_scores_rating                          4613 non-null   float64
#  60  review_scores_accuracy                        4606 non-null   float64
#  61  review_scores_cleanliness                     4606 non-null   float64
#  62  review_scores_checkin                         4606 non-null   float64
#  63  review_scores_communication                   4606 non-null   float64
#  64  review_scores_location                        4606 non-null   float64
#  65  review_scores_value                           4606 non-null   float64
#  66  license                                       3933 non-null   object
#  67  instant_bookable                              5355 non-null   object
#  68  calculated_host_listings_count                5355 non-null   int64
#  69  calculated_host_listings_count_entire_homes   5355 non-null   int64
#  70  calculated_host_listings_count_private_rooms  5355 non-null   int64
#  71  calculated_host_listings_count_shared_rooms   5355 non-null   int64
#  72  reviews_per_month                             4613 non-null   float64
#  73  available                                     5353 non-null   float64
#  74  price                                         5353 non-null   float64
#  75  revenue                                       5353 non-null   float64
#  76  daily_revenue                                 5353 non-null   float64
#  77  booking_rate(%)                               5353 non-null   float64
#  78  price_avg                                     5353 non-null   float64
#  79  price_std                                     5353 non-null   float64
#  80  price_per_person                              5353 non-null   float64
#  81  accom_per_bed                                 5269 non-null   float64
#  82  price_surge_percent                           5353 non-null   float64
#  83  price_std_percent                             5353 non-null   float64
# dtypes: float64(31), int64(19), object(34)
# memory usage: 3.5+ MB

# %%
#removed the columns with null values
cleaned_df = cleaned_df.drop(['bathrooms','calendar_updated'], axis = 1)
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5355 entries, 0 to 5354
# Data columns (total 82 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5355 non-null   int64
#  1   listing_url                                   5355 non-null   object
#  2   scrape_id                                     5355 non-null   int64
#  3   last_scraped                                  5355 non-null   object
#  4   name                                          5355 non-null   object
#  5   description                                   5348 non-null   object
#  6   neighborhood_overview                         4000 non-null   object
#  7   picture_url                                   5355 non-null   object
#  8   host_id                                       5355 non-null   int64
#  9   host_url                                      5355 non-null   object
#  10  host_name                                     5355 non-null   object
#  11  host_since                                    5355 non-null   object
#  12  host_location                                 5351 non-null   object
#  13  host_about                                    3871 non-null   object
#  14  host_response_time                            4862 non-null   object
#  15  host_response_rate                            4862 non-null   object
#  16  host_acceptance_rate                          5009 non-null   object
#  17  host_is_superhost                             5355 non-null   object
#  18  host_thumbnail_url                            5355 non-null   object
#  19  host_picture_url                              5355 non-null   object
#  20  host_neighbourhood                            4875 non-null   object
#  21  host_listings_count                           5355 non-null   int64
#  22  host_total_listings_count                     5355 non-null   int64
#  23  host_verifications                            5355 non-null   object
#  24  host_has_profile_pic                          5355 non-null   object
#  25  host_identity_verified                        5355 non-null   object
#  26  neighbourhood                                 4000 non-null   object
#  27  neighbourhood_cleansed                        5355 non-null   object
#  28  neighbourhood_group_cleansed                  5355 non-null   object
#  29  latitude                                      5355 non-null   float64
#  30  longitude                                     5355 non-null   float64
#  31  property_type                                 5355 non-null   object
#  32  room_type                                     5355 non-null   object
#  33  accommodates                                  5355 non-null   int64
#  34  bathrooms_text                                5352 non-null   object
#  35  bedrooms                                      4716 non-null   float64
#  36  beds                                          5269 non-null   float64
#  37  amenities                                     5355 non-null   object
#  38  minimum_nights                                5355 non-null   int64
#  39  maximum_nights                                5355 non-null   int64
#  40  minimum_minimum_nights                        5353 non-null   float64
#  41  maximum_minimum_nights                        5353 non-null   float64
#  42  minimum_maximum_nights                        5353 non-null   float64
#  43  maximum_maximum_nights                        5353 non-null   float64
#  44  minimum_nights_avg_ntm                        5353 non-null   float64
#  45  maximum_nights_avg_ntm                        5353 non-null   float64
#  46  has_availability                              5355 non-null   object
#  47  availability_30                               5355 non-null   int64
#  48  availability_60                               5355 non-null   int64
#  49  availability_90                               5355 non-null   int64
#  50  availability_365                              5355 non-null   int64
#  51  calendar_last_scraped                         5355 non-null   object
#  52  number_of_reviews                             5355 non-null   int64
#  53  number_of_reviews_ltm                         5355 non-null   int64
#  54  number_of_reviews_l30d                        5355 non-null   int64
#  55  first_review                                  4613 non-null   object
#  56  last_review                                   4613 non-null   object
#  57  review_scores_rating                          4613 non-null   float64
#  58  review_scores_accuracy                        4606 non-null   float64
#  59  review_scores_cleanliness                     4606 non-null   float64
#  60  review_scores_checkin                         4606 non-null   float64
#  61  review_scores_communication                   4606 non-null   float64
#  62  review_scores_location                        4606 non-null   float64
#  63  review_scores_value                           4606 non-null   float64
#  64  license                                       3933 non-null   object
#  65  instant_bookable                              5355 non-null   object
#  66  calculated_host_listings_count                5355 non-null   int64
#  67  calculated_host_listings_count_entire_homes   5355 non-null   int64
#  68  calculated_host_listings_count_private_rooms  5355 non-null   int64
#  69  calculated_host_listings_count_shared_rooms   5355 non-null   int64
#  70  reviews_per_month                             4613 non-null   float64
#  71  available                                     5353 non-null   float64
#  72  price                                         5353 non-null   float64
#  73  revenue                                       5353 non-null   float64
#  74  daily_revenue                                 5353 non-null   float64
#  75  booking_rate(%)                               5353 non-null   float64
#  76  price_avg                                     5353 non-null   float64
#  77  price_std                                     5353 non-null   float64
#  78  price_per_person                              5353 non-null   float64
#  79  accom_per_bed                                 5269 non-null   float64
#  80  price_surge_percent                           5353 non-null   float64
#  81  price_std_percent                             5353 non-null   float64
# dtypes: float64(29), int64(19), object(34)
# memory usage: 3.4+ MB

# %%
cat_col = list(cleaned_df.select_dtypes('object').columns)
len(cat_col)
# Out:
# 34

# %%
cols='''host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_neighbourhood, host_total_listings_count, host_verifications,host_identity_verified, neighbourhood,
property_type, room_type, bedrooms,minimum_nights,maximum_nights, has_availability, availability_30, number_of_reviews,number_of_reviews_ltm, number_of_reviews_l30d, review_scores_rating,review_scores_accuracy,review_scores_cleanliness,	review_scores_checkin,review_scores_communication,	review_scores_location,review_scores_value
, instant_bookable,price,price_avg,price_std, beds,accommodates,reviews_per_month,availability_60,availability_90,availability_365, revenue, booking_rate(%),bathrooms_text, price_per_person,accom_per_bed,price_surge_percent,price_std_percent'''

# %%
list(cols.split(','))
# Out:
# ['host_location',
#  ' host_response_time',
#  ' host_response_rate',
#  ' host_acceptance_rate',
#  ' host_is_superhost',
#  ' host_neighbourhood',
#  ' host_total_listings_count',
#  ' host_verifications',
#  'host_identity_verified',
#  ' neighbourhood',
#  '\nproperty_type',
#  ' room_type',
#  ' bedrooms',
#  'minimum_nights',
#  'maximum_nights',
#  ' has_availability',
#  ' availability_30',
#  ' number_of_reviews',
#  'number_of_reviews_ltm',
#  ' number_of_reviews_l30d',
#  ' review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  '\treview_scores_checkin',
#  'review_scores_communication',
#  '\treview_scores_location',
#  'review_scores_value\n',
#  ' instant_bookable',
#  'price',
#  'price_avg',
#  'price_std',
#  ' beds',
#  'accommodates',
#  'reviews_per_month',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  ' revenue',
#  ' booking_rate(%)',
#  'bathrooms_text',
#  ' price_per_person',
#  'accom_per_bed',
#  'price_surge_percent',
#  'price_std_percent']

# %%
len(list(cols.split(',')))
# Out:
# 44

# %%
columns=[]
for col in cols.split(','):
  columns.append(col.strip())

# %%
cleaned_df=cleaned_df[columns]

# %% [markdown]
# ## Handling null values

# %%
cleaned_df['host_location']=cleaned_df['host_location'].fillna('host location not available')

# %%
cleaned_df['host_response_rate'] = cleaned_df['host_response_rate'].str.replace('%','').astype('float64')
cleaned_df['host_acceptance_rate'] = cleaned_df['host_acceptance_rate'].str.replace('%','').astype('float64')

cleaned_df['host_response_rate']=cleaned_df['host_response_rate'].fillna(cleaned_df['host_response_rate'].mean())
cleaned_df['host_acceptance_rate']=cleaned_df['host_acceptance_rate'].fillna(cleaned_df['host_acceptance_rate'].mean())

# %%
cleaned_df['host_response_time']=cleaned_df['host_response_time'].fillna('response not available')
cleaned_df['host_is_superhost']=cleaned_df['host_is_superhost'].fillna(cleaned_df['host_is_superhost'].mode()[0])
cleaned_df['host_neighbourhood']=cleaned_df['host_neighbourhood'].fillna('host neighbourhood not available')
cleaned_df['neighbourhood']=cleaned_df['neighbourhood'].fillna('neighbourhood not available')

# %%
cleaned_df['bedrooms']=cleaned_df['bedrooms'].fillna(cleaned_df['bedrooms'].mean())
cleaned_df['review_scores_rating']=cleaned_df['review_scores_rating'].fillna(cleaned_df['review_scores_rating'].mean())
cleaned_df['review_scores_accuracy']=cleaned_df['review_scores_accuracy'].fillna(cleaned_df['review_scores_accuracy'].mean())
cleaned_df['review_scores_cleanliness']=cleaned_df['review_scores_cleanliness'].fillna(cleaned_df['review_scores_cleanliness'].mean())
cleaned_df['review_scores_checkin']=cleaned_df['review_scores_checkin'].fillna(cleaned_df['review_scores_checkin'].mean())
cleaned_df['review_scores_communication']=cleaned_df['review_scores_communication'].fillna(cleaned_df['review_scores_communication'].mean())
cleaned_df['review_scores_location']=cleaned_df['review_scores_location'].fillna(cleaned_df['review_scores_location'].mean())
cleaned_df['review_scores_value']=cleaned_df['review_scores_value'].fillna(cleaned_df['review_scores_value'].mean())
cleaned_df['reviews_per_month']=cleaned_df['reviews_per_month'].fillna(cleaned_df['reviews_per_month'].mean())
cleaned_df['revenue']=cleaned_df['revenue'].fillna(cleaned_df['revenue'].mean())
cleaned_df['booking_rate(%)']=cleaned_df['booking_rate(%)'].fillna(cleaned_df['booking_rate(%)'].mean())
cleaned_df['price_per_person']=cleaned_df['price_per_person'].fillna(cleaned_df['price_per_person'].mean())
cleaned_df['accom_per_bed']=cleaned_df['accom_per_bed'].fillna(cleaned_df['accom_per_bed'].mean())
cleaned_df['price_surge_percent']=cleaned_df['price_surge_percent'].fillna(cleaned_df['price_surge_percent'].mean())
cleaned_df['price_std_percent']=cleaned_df['price_std_percent'].fillna(cleaned_df['price_std_percent'].mean())
cleaned_df['price']=cleaned_df['price'].fillna(cleaned_df['price'].mean())
cleaned_df['price_avg']=cleaned_df['price_avg'].fillna(cleaned_df['price_avg'].mean())
cleaned_df['price_std']=cleaned_df['price_std'].fillna(cleaned_df['price_std'].mean())
cleaned_df['beds']=cleaned_df['beds'].fillna(cleaned_df['beds'].mean())
cleaned_df['bathrooms_text']=cleaned_df['bathrooms_text'].fillna(cleaned_df['bathrooms_text'].mode()[0])

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5355 entries, 0 to 5354
# Data columns (total 44 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_location                5355 non-null   object
#  1   host_response_time           5355 non-null   object
#  2   host_response_rate           5355 non-null   float64
#  3   host_acceptance_rate         5355 non-null   float64
#  4   host_is_superhost            5355 non-null   object
#  5   host_neighbourhood           5355 non-null   object
#  6   host_total_listings_count    5355 non-null   int64
#  7   host_verifications           5355 non-null   object
#  8   host_identity_verified       5355 non-null   object
#  9   neighbourhood                5355 non-null   object
#  10  property_type                5355 non-null   object
#  11  room_type                    5355 non-null   object
#  12  bedrooms                     5355 non-null   float64
#  13  minimum_nights               5355 non-null   int64
#  14  maximum_nights               5355 non-null   int64
#  15  has_availability             5355 non-null   object
#  16  availability_30              5355 non-null   int64
#  17  number_of_reviews            5355 non-null   int64
#  18  number_of_reviews_ltm        5355 non-null   int64
#  19  number_of_reviews_l30d       5355 non-null   int64
#  20  review_scores_rating         5355 non-null   float64
#  21  review_scores_accuracy       5355 non-null   float64
#  22  review_scores_cleanliness    5355 non-null   float64
#  23  review_scores_checkin        5355 non-null   float64
#  24  review_scores_communication  5355 non-null   float64
#  25  review_scores_location       5355 non-null   float64
#  26  review_scores_value          5355 non-null   float64
#  27  instant_bookable             5355 non-null   object
#  28  price                        5355 non-null   float64
#  29  price_avg                    5355 non-null   float64
#  30  price_std                    5355 non-null   float64
#  31  beds                         5355 non-null   float64
#  32  accommodates                 5355 non-null   int64
#  33  reviews_per_month            5355 non-null   float64
#  34  availability_60              5355 non-null   int64
#  35  availability_90              5355 non-null   int64
#  36  availability_365             5355 non-null   int64
#  37  revenue                      5355 non-null   float64
#  38  booking_rate(%)              5355 non-null   float64
#  39  bathrooms_text               5355 non-null   object
#  40  price_per_person             5355 non-null   float64
#  41  accom_per_bed                5355 non-null   float64
#  42  price_surge_percent          5355 non-null   float64
#  43  price_std_percent            5355 non-null   float64
# dtypes: float64(21), int64(11), object(12)
# memory usage: 1.8+ MB

# %% [markdown]
# # **3. Insights**

# %% [markdown]
# ## Top 5 property types for best returns?

# %%
cleaned_df.groupby("property_type").mean()['revenue'].sort_values(ascending=False).iloc[:5].plot(kind='bar')
plt.ylabel('average revenue')
plt.xlabel('property_type')
plt.title('Top 5 property types by revenue')
plt.show()

# %%
cleaned_df.groupby("property_type").mean()['revenue'].sort_values(ascending=False).iloc[:5]
# Out:
# property_type
# Entire place                         496.131507
# Private room in bed and breakfast    267.558493
# Entire villa                         186.445010
# Entire serviced apartment            147.674082
# Entire home                          146.632533
# Name: revenue, dtype: float64

# %% [markdown]
# ## Top 5 property types with the highest booking rate?

# %%
cleaned_df.groupby("property_type").mean()['booking_rate(%)'].sort_values(ascending=False).iloc[:5].plot(kind='bar')
plt.xlabel('property_type')
plt.ylabel('average booking rate(%)')
plt.title('Top 5 property types by booking rate')
plt.show()

# %%
cleaned_df.groupby("property_type").mean()['booking_rate(%)'].sort_values(ascending=False).iloc[:5]
# Out:
# property_type
# Tent                                  100.000000
# Private room in serviced apartment    100.000000
# Entire place                           91.780822
# Shared room                            79.315068
# Entire serviced apartment              78.897847
# Name: booking_rate(%), dtype: float64

# %% [markdown]
# ## What are the top 5 neighborhoods/areas to invest in based on average revenue?

# %%
cleaned_df.groupby('neighbourhood').mean()['revenue'].sort_values(ascending=False).iloc[:5].plot(kind='bar')
plt.xlabel('neighbourhood')
plt.ylabel('average revenue')
plt.title('Top 5 neighborhoods by revenue')
plt.show()

# %%
cleaned_df.groupby('neighbourhood').mean()['revenue'].sort_values(ascending=False).iloc[:5]
# Out:
# neighbourhood
# Seattle, Wa, United States                  262.194521
# Renton, Washington, United States           256.201370
# Mercer Island, Washington, United States    213.749315
# Seattle , Washington, United States         164.506849
# neighbourhood not available                 126.761795
# Name: revenue, dtype: float64

# %% [markdown]
# ## What are the top 5 neighborhoods/areas to invest in based on booking rate?

# %%
cleaned_df.groupby('neighbourhood').mean()['booking_rate(%)'].sort_values(ascending=False).iloc[:5].plot(kind='bar')
plt.xlabel('neighbourhood')
plt.ylabel('average booking rate(%)')
plt.title('Top 5 neighborhoods by booking rate')
plt.show()

# %%
cleaned_df.groupby('neighbourhood').mean()['booking_rate(%)'].sort_values(ascending=False).iloc[:5]
# Out:
# neighbourhood
# Seattle , Washington, United States                    92.328767
# Renton, Washington, United States                      66.986301
# West Seattle, Washington, Washington, United States    63.835616
# neighbourhood not available                            58.646625
# West Seattle, Washington, United States                57.534247
# Name: booking_rate(%), dtype: float64

# %% [markdown]
# ## How does maximum number of people per listing affect revenue/booking rate?

# %%
#plt.figure(figsize =(10,10))
cleaned_df.groupby('accommodates').mean()[['booking_rate(%)','revenue']].plot(kind='bar')
plt.xlabel('accommodates')
plt.ylabel('average booking rate(%)/revenue')
plt.title('Effect of accommodations on booking rate/revenue')
plt.show()

# %% [markdown]
# Number of accommodates does not affect booking rate(%) but it affects revenue.

# %% [markdown]
# ## Effect of verification on booking rate and revenue

# %%
cleaned_df.groupby('host_identity_verified').mean()['revenue'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='host_identity_verified'>

# %% [markdown]
# Verifying your identity might increase revenue.

# %%
cleaned_df.groupby('host_identity_verified').mean()['booking_rate(%)'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='host_identity_verified'>

# %% [markdown]
# Verifying your identity might increase booking rate.

# %% [markdown]
# ## How review ratings affect revenue and booking rate?

# %%
import matplotlib.pyplot as plt
plt.scatter(cleaned_df['review_scores_rating'],cleaned_df['revenue'])
plt.xlabel('review_scores_rating')
plt.ylabel('revenue')
plt.title('review_scores_rating vs revenue')
plt.show()

# %% [markdown]
# Rating above 4 might suggest higher revenue. Although all the values are saturated towards the end.

# %%
plt.scatter(cleaned_df['review_scores_rating'],cleaned_df['booking_rate(%)'])
plt.xlabel('review_scores_rating')
plt.ylabel('booking_rate(%)')
plt.title('review_scores_rating vs booking_rate(%)')
plt.show()

# %% [markdown]
# All the values are saturated towards the end which makes it difficult to say whether having lower/higher review rating will affect booking rate based on the sample.

# %% [markdown]
# ## Seasonal pattern

# %%
cleaned_df['date'] = pd.to_datetime(cal['date'])
cleaned_df['day_of_week'] = cleaned_df['date'].dt.day_name()

revenu_per_week=cleaned_df.groupby('day_of_week').revenue.mean().reset_index()

plt.figure(figsize=(10,7))
plt.plot(revenu_per_week['day_of_week'],revenu_per_week['revenue'],marker='o')
plt.xticks(rotation=90)
plt.xlabel('day_of_week')
plt.ylabel('revenue')
plt.title('Day of week vs revenue')
plt.show()

# %%
cleaned_df.drop(['date','day_of_week'],axis=1,inplace=True)

# %% [markdown]
# # **4. Feature Selection**

# %%
cleaned_df.info()
import numpy as np
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5355 entries, 0 to 5354
# Data columns (total 44 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_location                5355 non-null   object
#  1   host_response_time           5355 non-null   object
#  2   host_response_rate           5355 non-null   float64
#  3   host_acceptance_rate         5355 non-null   float64
#  4   host_is_superhost            5355 non-null   object
#  5   host_neighbourhood           5355 non-null   object
#  6   host_total_listings_count    5355 non-null   int64
#  7   host_verifications           5355 non-null   object
#  8   host_identity_verified       5355 non-null   object
#  9   neighbourhood                5355 non-null   object
#  10  property_type                5355 non-null   object
#  11  room_type                    5355 non-null   object
#  12  bedrooms                     5355 non-null   float64
#  13  minimum_nights               5355 non-null   int64
#  14  maximum_nights               5355 non-null   int64
#  15  has_availability             5355 non-null   object
#  16  availability_30              5355 non-null   int64
#  17  number_of_reviews            5355 non-null   int64
#  18  number_of_reviews_ltm        5355 non-null   int64
#  19  number_of_reviews_l30d       5355 non-null   int64
#  20  review_scores_rating         5355 non-null   float64
#  21  review_scores_accuracy       5355 non-null   float64
#  22  review_scores_cleanliness    5355 non-null   float64
#  23  review_scores_checkin        5355 non-null   float64
#  24  review_scores_communication  5355 non-null   float64
#  25  review_scores_location       5355 non-null   float64
#  26  review_scores_value          5355 non-null   float64
#  27  instant_bookable             5355 non-null   object
#  28  price                        5355 non-null   float64
#  29  price_avg                    5355 non-null   float64
#  30  price_std                    5355 non-null   float64
#  31  beds                         5355 non-null   float64
#  32  accommodates                 5355 non-null   int64
#  33  reviews_per_month            5355 non-null   float64
#  34  availability_60              5355 non-null   int64
#  35  availability_90              5355 non-null   int64
#  36  availability_365             5355 non-null   int64
#  37  revenue                      5355 non-null   float64
#  38  booking_rate(%)              5355 non-null   float64
#  39  bathrooms_text               5355 non-null   object
#  40  price_per_person             5355 non-null   float64
#  41  accom_per_bed                5355 non-null   float64
#  42  price_surge_percent          5355 non-null   float64
#  43  price_std_percent            5355 non-null   float64
# dtypes: float64(21), int64(11), object(12)
# memory usage: 1.8+ MB

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from xgboost import XGBRegressor

# %% [markdown]
# host_location,host_neighbourhood,property_type,bathrooms_text,neighbourhood
# The above features may causes 'curse of dimensionality', So we are considering only top n features of this columns and rest of categories of features considered as noise, we impute them with 0.

# %%
top_5 = [x for x in cleaned_df.host_location.value_counts().sort_values(ascending=False).head(5).index]
for label in top_5:
      cleaned_df[label] = np.where(cleaned_df['host_location']==label,1,0)
cleaned_df[['host_location']+top_5]
cleaned_df.drop('host_location',axis=1,inplace=True)

# %%
top_10 = [x for x in cleaned_df.host_neighbourhood.value_counts().sort_values(ascending=False).head(10).index]
for label in top_10:
      cleaned_df[label] = np.where(cleaned_df['host_neighbourhood']==label,1,0)
cleaned_df[['host_neighbourhood']+top_10]
cleaned_df.drop('host_neighbourhood',axis=1,inplace=True)

# %%
top_5 = [x for x in cleaned_df.property_type.value_counts().sort_values(ascending=False).head(5).index]
for label in top_5:
      cleaned_df[label] = np.where(cleaned_df['property_type']==label,1,0)
cleaned_df[['property_type']+top_5]
cleaned_df.drop('property_type',axis=1,inplace=True)

# %%
top_7 = [x for x in cleaned_df.bathrooms_text.value_counts().sort_values(ascending=False).head(7).index]
for label in top_7:
      cleaned_df[label] = np.where(cleaned_df['bathrooms_text']==label,1,0)
cleaned_df[['bathrooms_text']+top_7]
cleaned_df.drop('bathrooms_text',axis=1,inplace=True)

# %%
top_5 = [x for x in cleaned_df.neighbourhood.value_counts().sort_values(ascending=False).head(5).index]
for label in top_5:
      cleaned_df[label] = np.where(cleaned_df['neighbourhood']==label,1,0)
cleaned_df[['neighbourhood']+top_5]
cleaned_df.drop('neighbourhood',axis=1,inplace=True)

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5355 entries, 0 to 5354
# Data columns (total 64 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   host_response_time                           5355 non-null   object
#  1   host_response_rate                           5355 non-null   float64
#  2   host_acceptance_rate                         5355 non-null   float64
#  3   host_is_superhost                            5355 non-null   object
#  4   host_total_listings_count                    5355 non-null   int64
#  5   host_verifications                           5355 non-null   object
#  6   host_identity_verified                       5355 non-null   object
#  7   room_type                                    5355 non-null   object
#  8   bedrooms                                     5355 non-null   float64
#  9   minimum_nights                               5355 non-null   int64
#  10  maximum_nights                               5355 non-null   int64
#  11  has_availability                             5355 non-null   object
#  12  availability_30                              5355 non-null   int64
#  13  number_of_reviews                            5355 non-null   int64
#  14  number_of_reviews_ltm                        5355 non-null   int64
#  15  number_of_reviews_l30d                       5355 non-null   int64
#  16  review_scores_rating                         5355 non-null   float64
#  17  review_scores_accuracy                       5355 non-null   float64
#  18  review_scores_cleanliness                    5355 non-null   float64
#  19  review_scores_checkin                        5355 non-null   float64
#  20  review_scores_communication                  5355 non-null   float64
#  21  review_scores_location                       5355 non-null   float64
#  22  review_scores_value                          5355 non-null   float64
#  23  instant_bookable                             5355 non-null   object
#  24  price                                        5355 non-null   float64
#  25  price_avg                                    5355 non-null   float64
#  26  price_std                                    5355 non-null   float64
#  27  beds                                         5355 non-null   float64
#  28  accommodates                                 5355 non-null   int64
#  29  reviews_per_month                            5355 non-null   float64
#  30  availability_60                              5355 non-null   int64
#  31  availability_90                              5355 non-null   int64
#  32  availability_365                             5355 non-null   int64
#  33  revenue                                      5355 non-null   float64
#  34  booking_rate(%)                              5355 non-null   float64
#  35  bathrooms_text                               5355 non-null   object
#  36  price_per_person                             5355 non-null   float64
#  37  accom_per_bed                                5355 non-null   float64
#  38  price_surge_percent                          5355 non-null   float64
#  39  price_std_percent                            5355 non-null   float64
#  40  Seattle, Washington, United States           5355 non-null   int64
#  41  US                                           5355 non-null   int64
#  42  New York, New York, United States            5355 non-null   int64
#  43  San Francisco, California, United States     5355 non-null   int64
#  44  Bellevue, Washington, United States          5355 non-null   int64
#  45  host neighbourhood not available             5355 non-null   int64
#  46  Capitol Hill                                 5355 non-null   int64
#  47  Cambridge                                    5355 non-null   int64
#  48  Minor                                        5355 non-null   int64
#  49  West Seattle                                 5355 non-null   int64
#  50  Wallingford                                  5355 non-null   int64
#  51  Queen Anne                                   5355 non-null   int64
#  52  Northeast Seattle                            5355 non-null   int64
#  53  Ballard                                      5355 non-null   int64
#  54  Northwest Seattle                            5355 non-null   int64
#  55  Entire rental unit                           5355 non-null   int64
#  56  Entire home                                  5355 non-null   int64
#  57  Entire guest suite                           5355 non-null   int64
#  58  Entire condo                                 5355 non-null   int64
#  59  Private room in home                         5355 non-null   int64
#  60  neighbourhood not available                  5355 non-null   int64
#  61  Shoreline, Washington, United States         5355 non-null   int64
#  62  Lake Forest Park, Washington, United States  5355 non-null   int64
#  63  Burien, Washington, United States            5355 non-null   int64
# dtypes: float64(21), int64(35), object(8)
# memory usage: 2.7+ MB

# %% [markdown]
# **Create dummies**

# %%
dummy_airbnb=pd.get_dummies(cleaned_df,drop_first=True)

# %%
dummy_airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5355 entries, 0 to 5354
# Data columns (total 94 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   host_response_rate                           5355 non-null   float64
#  1   host_acceptance_rate                         5355 non-null   float64
#  2   host_total_listings_count                    5355 non-null   int64
#  3   bedrooms                                     5355 non-null   float64
#  4   minimum_nights                               5355 non-null   int64
#  5   maximum_nights                               5355 non-null   int64
#  6   availability_30                              5355 non-null   int64
#  7   number_of_reviews                            5355 non-null   int64
#  8   number_of_reviews_ltm                        5355 non-null   int64
#  9   number_of_reviews_l30d                       5355 non-null   int64
#  10  review_scores_rating                         5355 non-null   float64
#  11  review_scores_accuracy                       5355 non-null   float64
#  12  review_scores_cleanliness                    5355 non-null   float64
#  13  review_scores_checkin                        5355 non-null   float64
#  14  review_scores_communication                  5355 non-null   float64
#  15  review_scores_location                       5355 non-null   float64
#  16  review_scores_value                          5355 non-null   float64
#  17  price                                        5355 non-null   float64
#  18  price_avg                                    5355 non-null   float64
#  19  price_std                                    5355 non-null   float64
#  20  beds                                         5355 non-null   float64
#  21  accommodates                                 5355 non-null   int64
#  22  reviews_per_month                            5355 non-null   float64
#  23  availability_60                              5355 non-null   int64
#  24  availability_90                              5355 non-null   int64
#  25  availability_365                             5355 non-null   int64
#  26  revenue                                      5355 non-null   float64
#  27  booking_rate(%)                              5355 non-null   float64
#  28  price_per_person                             5355 non-null   float64
#  29  accom_per_bed                                5355 non-null   float64
#  30  price_surge_percent                          5355 non-null   float64
#  31  price_std_percent                            5355 non-null   float64
#  32  Seattle, Washington, United States           5355 non-null   int64
#  33  US                                           5355 non-null   int64
#  34  New York, New York, United States            5355 non-null   int64
#  35  San Francisco, California, United States     5355 non-null   int64
#  36  Bellevue, Washington, United States          5355 non-null   int64
#  37  host neighbourhood not available             5355 non-null   int64
#  38  Capitol Hill                                 5355 non-null   int64
#  39  Cambridge                                    5355 non-null   int64
#  40  Minor                                        5355 non-null   int64
#  41  West Seattle                                 5355 non-null   int64
#  42  Wallingford                                  5355 non-null   int64
#  43  Queen Anne                                   5355 non-null   int64
#  44  Northeast Seattle                            5355 non-null   int64
#  45  Ballard                                      5355 non-null   int64
#  46  Northwest Seattle                            5355 non-null   int64
#  47  Entire rental unit                           5355 non-null   int64
#  48  Entire home                                  5355 non-null   int64
#  49  Entire guest suite                           5355 non-null   int64
#  50  Entire condo                                 5355 non-null   int64
#  51  Private room in home                         5355 non-null   int64
#  52  neighbourhood not available                  5355 non-null   int64
#  53  Shoreline, Washington, United States         5355 non-null   int64
#  54  Lake Forest Park, Washington, United States  5355 non-null   int64
#  55  Burien, Washington, United States            5355 non-null   int64
#  56  host_response_time_response not available    5355 non-null   uint8
#  57  host_response_time_within a day              5355 non-null   uint8
#  58  host_response_time_within a few hours        5355 non-null   uint8
#  59  host_response_time_within an hour            5355 non-null   uint8
#  60  host_is_superhost_t                          5355 non-null   uint8
#  61  host_verifications_['email', 'phone']        5355 non-null   uint8
#  62  host_verifications_['email']                 5355 non-null   uint8
#  63  host_verifications_['phone', 'work_email']   5355 non-null   uint8
#  64  host_verifications_['phone']                 5355 non-null   uint8
#  65  host_identity_verified_t                     5355 non-null   uint8
#  66  room_type_Hotel room                         5355 non-null   uint8
#  67  room_type_Private room                       5355 non-null   uint8
#  68  room_type_Shared room                        5355 non-null   uint8
#  69  has_availability_t                           5355 non-null   uint8
#  70  instant_bookable_t                           5355 non-null   uint8
#  71  bathrooms_text_0 shared baths                5355 non-null   uint8
#  72  bathrooms_text_1 bath                        5355 non-null   uint8
#  73  bathrooms_text_1 private bath                5355 non-null   uint8
#  74  bathrooms_text_1 shared bath                 5355 non-null   uint8
#  75  bathrooms_text_1.5 baths                     5355 non-null   uint8
#  76  bathrooms_text_1.5 shared baths              5355 non-null   uint8
#  77  bathrooms_text_16 shared baths               5355 non-null   uint8
#  78  bathrooms_text_2 baths                       5355 non-null   uint8
#  79  bathrooms_text_2 shared baths                5355 non-null   uint8
#  80  bathrooms_text_2.5 baths                     5355 non-null   uint8
#  81  bathrooms_text_2.5 shared baths              5355 non-null   uint8
#  82  bathrooms_text_3 baths                       5355 non-null   uint8
#  83  bathrooms_text_3 shared baths                5355 non-null   uint8
#  84  bathrooms_text_3.5 baths                     5355 non-null   uint8
#  85  bathrooms_text_3.5 shared baths              5355 non-null   uint8
#  86  bathrooms_text_4 baths                       5355 non-null   uint8
#  87  bathrooms_text_4 shared baths                5355 non-null   uint8
#  88  bathrooms_text_4.5 baths                     5355 non-null   uint8
#  89  bathrooms_text_5 baths                       5355 non-null   uint8
#  90  bathrooms_text_6 baths                       5355 non-null   uint8
#  91  bathrooms_text_Half-bath                     5355 non-null   uint8
#  92  bathrooms_text_Private half-bath             5355 non-null   uint8
#  93  bathrooms_text_Shared half-bath              5355 non-null   uint8
# dtypes: float64(21), int64(35), uint8(38)
# memory usage: 2.5 MB

# %%
#creating independent(x_revenue) and dependent i.e Target variable(y_revenue)
X_revenue = dummy_airbnb.drop(['revenue','booking_rate(%)'],axis=1)
y_revenue = dummy_airbnb.revenue

# %% [markdown]
# AdaBoost for feature selection

# %%
from sklearn.ensemble import AdaBoostRegressor
regr = AdaBoostRegressor(random_state=0)
params = {'n_estimators' : [50,100],'learning_rate':[0.3,0.6,1]}
kfold = KFold(n_splits=5,shuffle=True,random_state=2022)

gcv = GridSearchCV(regr,param_grid=params,scoring='r2',cv=kfold,verbose=3)
gcv.fit(X_revenue,y_revenue)

print(gcv.best_params_)
print(gcv.best_score_)

# %%
# Sorted Imp Plot
plt.figure(figsize=(20,20))
best_model = gcv.best_estimator_
col_names=X_revenue.columns
importance = best_model.feature_importances_
#sorted plot
neg_imp=-1*importance
i_desc_sorted=neg_imp.argsort()
imp_sorted=importance[i_desc_sorted]
col_sorted=col_names[i_desc_sorted]
plt.title('Sorted features')
plt.bar(col_sorted,imp_sorted)
plt.xticks(rotation=90)
plt.ylabel('importances')
plt.show()

# %%
selected_features = col_sorted[:20]

# %%
selected_features
# Out:
# Index(['price', 'price_avg', 'price_per_person', 'availability_365', 'beds',
#        'accommodates', 'availability_60', 'review_scores_rating',
#        'reviews_per_month', 'availability_30', '1 bath', 'accom_per_bed',
#        'minimum_nights', '2 baths', 'host_total_listings_count',
#        'host_response_time_within an hour', 'review_scores_checkin',
#        'Entire home', 'review_scores_communication', 'bedrooms'],
#       dtype='object')

# %%
plt.figure(figsize=(25,16))
sns.heatmap(dummy_airbnb[selected_features].corr(),annot=True,cmap="YlGnBu",annot_kws={'size': 15},cbar=True)
plt.show()

# %%
dummy_airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5355 entries, 0 to 5354
# Data columns (total 78 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   host_response_rate                           5355 non-null   float64
#  1   host_acceptance_rate                         5355 non-null   float64
#  2   host_total_listings_count                    5355 non-null   int64
#  3   bedrooms                                     5355 non-null   float64
#  4   minimum_nights                               5355 non-null   int64
#  5   maximum_nights                               5355 non-null   int64
#  6   availability_30                              5355 non-null   int64
#  7   number_of_reviews                            5355 non-null   int64
#  8   number_of_reviews_ltm                        5355 non-null   int64
#  9   number_of_reviews_l30d                       5355 non-null   int64
#  10  review_scores_rating                         5355 non-null   float64
#  11  review_scores_accuracy                       5355 non-null   float64
#  12  review_scores_cleanliness                    5355 non-null   float64
#  13  review_scores_checkin                        5355 non-null   float64
#  14  review_scores_communication                  5355 non-null   float64
#  15  review_scores_location                       5355 non-null   float64
#  16  review_scores_value                          5355 non-null   float64
#  17  price                                        5355 non-null   float64
#  18  price_avg                                    5355 non-null   float64
#  19  price_std                                    5355 non-null   float64
#  20  beds                                         5355 non-null   float64
#  21  accommodates                                 5355 non-null   int64
#  22  reviews_per_month                            5355 non-null   float64
#  23  availability_60                              5355 non-null   int64
#  24  availability_90                              5355 non-null   int64
#  25  availability_365                             5355 non-null   int64
#  26  revenue                                      5355 non-null   float64
#  27  booking_rate(%)                              5355 non-null   float64
#  28  price_per_person                             5355 non-null   float64
#  29  accom_per_bed                                5355 non-null   float64
#  30  price_surge_percent                          5355 non-null   float64
#  31  price_std_percent                            5355 non-null   float64
#  32  Seattle, Washington, United States           5355 non-null   int64
#  33  US                                           5355 non-null   int64
#  34  New York, New York, United States            5355 non-null   int64
#  35  San Francisco, California, United States     5355 non-null   int64
#  36  Bellevue, Washington, United States          5355 non-null   int64
#  37  host neighbourhood not available             5355 non-null   int64
#  38  Capitol Hill                                 5355 non-null   int64
#  39  Cambridge                                    5355 non-null   int64
#  40  Minor                                        5355 non-null   int64
#  41  West Seattle                                 5355 non-null   int64
#  42  Wallingford                                  5355 non-null   int64
#  43  Queen Anne                                   5355 non-null   int64
#  44  Northeast Seattle                            5355 non-null   int64
#  45  Ballard                                      5355 non-null   int64
#  46  Northwest Seattle                            5355 non-null   int64
#  47  Entire rental unit                           5355 non-null   int64
#  48  Entire home                                  5355 non-null   int64
#  49  Entire guest suite                           5355 non-null   int64
#  50  Entire condo                                 5355 non-null   int64
#  51  Private room in home                         5355 non-null   int64
#  52  1 bath                                       5355 non-null   int64
#  53  2 baths                                      5355 non-null   int64
#  54  1 shared bath                                5355 non-null   int64
#  55  1 private bath                               5355 non-null   int64
#  56  2.5 baths                                    5355 non-null   int64
#  57  1.5 baths                                    5355 non-null   int64
#  58  3 baths                                      5355 non-null   int64
#  59  neighbourhood not available                  5355 non-null   int64
#  60  Shoreline, Washington, United States         5355 non-null   int64
#  61  Lake Forest Park, Washington, United States  5355 non-null   int64
#  62  Burien, Washington, United States            5355 non-null   int64
#  63  host_response_time_response not available    5355 non-null   uint8
#  64  host_response_time_within a day              5355 non-null   uint8
#  65  host_response_time_within a few hours        5355 non-null   uint8
#  66  host_response_time_within an hour            5355 non-null   uint8
#  67  host_is_superhost_t                          5355 non-null   uint8
#  68  host_verifications_['email', 'phone']        5355 non-null   uint8
#  69  host_verifications_['email']                 5355 non-null   uint8
#  70  host_verifications_['phone', 'work_email']   5355 non-null   uint8
#  71  host_verifications_['phone']                 5355 non-null   uint8
#  72  host_identity_verified_t                     5355 non-null   uint8
#  73  room_type_Hotel room                         5355 non-null   uint8
#  74  room_type_Private room                       5355 non-null   uint8
#  75  room_type_Shared room                        5355 non-null   uint8
#  76  has_availability_t                           5355 non-null   uint8
#  77  instant_bookable_t                           5355 non-null   uint8
# dtypes: float64(21), int64(42), uint8(15)
# memory usage: 2.7 MB

# %%
dummy_airbnb.to_csv('preprocessed_airbnb',index = False)

# %% [markdown]
# # **5. Modeling**

# %%
#updated list of features and took only those who significantly impacted the Target variable
X_revenue = X_revenue[selected_features]

# %% [markdown]
# **DecisionTreeRegressor for model testing using selected_features**

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state=2022,max_depth=3)
kfold = KFold(n_splits=5,shuffle=True,random_state=2022)
params = {'max_depth':[None, 3, 5, 7],
          'min_samples_split':[2, 5, 10],
          'min_samples_leaf':[1, 3, 10]}

gcv = GridSearchCV(dtr, param_grid=params,scoring='r2',cv=kfold,verbose=3)
gcv.fit(X_revenue,y_revenue)
print(gcv.best_params_)        
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.941 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.965 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.874 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.881 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.970 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.963 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.967 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.723 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.888 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.968 total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.969 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.977 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.728 total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.883 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.969 total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=3, min_samples_split=2;, score=0.955 total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=3, min_samples_split=2;, score=0.977 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=3, min_samples_split=2;, score=0.726 total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=3, min_samples_split=2;, score=0.711 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=3, min_samples_split=2;, score=0.955 total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=3, min_samples_split=5;, score=0.955 total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=3, min_samples_split=5;, score=0.977 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=3, min_samples_split=5;, score=0.726 total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=3, min_samples_split=5;, score=0.711 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=3, min_samples_split=5;, score=0.955 total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=3, min_samples_split=10;, score=0.963 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=3, min_samples_split=10;, score=0.976 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=3, min_samples_split=10;, score=0.727 total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=3, min_samples_split=10;, score=0.683 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=3, min_samples_split=10;, score=0.967 total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=10, min_samples_split=2;, score=0.778 total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=10, min_samples_split=2;, score=0.766 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=10, min_samples_split=2;, score=0.915 total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=10, min_samples_split=2;, score=0.679 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=10, min_samples_split=2;, score=0.873 total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=10, min_samples_split=5;, score=0.778 total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=10, min_samples_split=5;, score=0.766 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=10, min_samples_split=5;, score=0.915 total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=10, min_samples_split=5;, score=0.679 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=10, min_samples_split=5;, score=0.873 total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=10, min_samples_split=10;, score=0.778 total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=10, min_samples_split=10;, score=0.766 total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=10, min_samples_split=10;, score=0.915 total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=10, min_samples_split=10;, score=0.679 total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=10, min_samples_split=10;, score=0.873 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.754 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.666 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.607 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.756 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.645 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=1, min_samples_split=5;, score=0.770 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=1, min_samples_split=5;, score=0.666 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=1, min_samples_split=5;, score=0.453 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=1, min_samples_split=5;, score=0.756 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=1, min_samples_split=5;, score=0.645 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=1, min_samples_split=10;, score=0.770 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=1, min_samples_split=10;, score=0.666 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=1, min_samples_split=10;, score=0.453 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=1, min_samples_split=10;, score=0.756 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=1, min_samples_split=10;, score=0.645 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=3, min_samples_split=2;, score=0.803 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=3, min_samples_split=2;, score=0.666 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=3, min_samples_split=2;, score=0.453 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=3, min_samples_split=2;, score=0.606 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=3, min_samples_split=2;, score=0.645 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=3, min_samples_split=5;, score=0.803 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=3, min_samples_split=5;, score=0.666 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=3, min_samples_split=5;, score=0.453 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=3, min_samples_split=5;, score=0.606 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=3, min_samples_split=5;, score=0.645 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=3, min_samples_split=10;, score=0.803 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=3, min_samples_split=10;, score=0.666 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=3, min_samples_split=10;, score=0.453 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=3, min_samples_split=10;, score=0.606 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=3, min_samples_split=10;, score=0.645 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=10, min_samples_split=2;, score=0.659 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=10, min_samples_split=2;, score=0.486 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=10, min_samples_split=2;, score=0.778 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=10, min_samples_split=2;, score=0.606 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=10, min_samples_split=2;, score=0.636 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=10, min_samples_split=5;, score=0.659 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=10, min_samples_split=5;, score=0.486 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=10, min_samples_split=5;, score=0.778 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=10, min_samples_split=5;, score=0.606 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=10, min_samples_split=5;, score=0.636 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=10, min_samples_split=10;, score=0.659 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=10, min_samples_split=10;, score=0.486 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=10, min_samples_split=10;, score=0.778 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=10, min_samples_split=10;, score=0.606 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=10, min_samples_split=10;, score=0.636 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=1, min_samples_split=2;, score=0.898 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=1, min_samples_split=2;, score=0.886 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=1, min_samples_split=2;, score=0.799 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=1, min_samples_split=2;, score=0.940 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=1, min_samples_split=2;, score=0.892 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=1, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=1, min_samples_split=5;, score=0.886 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=1, min_samples_split=5;, score=0.645 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=1, min_samples_split=5;, score=0.940 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=1, min_samples_split=5;, score=0.892 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=1, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=1, min_samples_split=10;, score=0.886 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=1, min_samples_split=10;, score=0.645 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=1, min_samples_split=10;, score=0.873 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=1, min_samples_split=10;, score=0.892 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=3, min_samples_split=2;, score=0.924 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=3, min_samples_split=2;, score=0.886 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=3, min_samples_split=2;, score=0.645 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=3, min_samples_split=2;, score=0.694 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=3, min_samples_split=2;, score=0.895 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=3, min_samples_split=5;, score=0.924 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=3, min_samples_split=5;, score=0.886 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=3, min_samples_split=5;, score=0.645 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=3, min_samples_split=5;, score=0.694 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=3, min_samples_split=5;, score=0.895 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=3, min_samples_split=10;, score=0.924 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=3, min_samples_split=10;, score=0.886 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=3, min_samples_split=10;, score=0.645 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=3, min_samples_split=10;, score=0.666 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=3, min_samples_split=10;, score=0.895 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=10, min_samples_split=2;, score=0.741 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=10, min_samples_split=2;, score=0.696 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=10, min_samples_split=2;, score=0.884 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=10, min_samples_split=2;, score=0.661 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=10, min_samples_split=2;, score=0.812 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=10, min_samples_split=5;, score=0.741 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=10, min_samples_split=5;, score=0.696 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=10, min_samples_split=5;, score=0.884 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=10, min_samples_split=5;, score=0.661 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=10, min_samples_split=5;, score=0.812 total time=   0.0s
# [CV 1/5] END max_depth=5, min_samples_leaf=10, min_samples_split=10;, score=0.741 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=10, min_samples_split=10;, score=0.696 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=10, min_samples_split=10;, score=0.884 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=10, min_samples_split=10;, score=0.661 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=10, min_samples_split=10;, score=0.812 total time=   0.0s
# [CV 1/5] END max_depth=7, min_samples_leaf=1, min_samples_split=2;, score=0.928 total time=   0.0s
# [CV 2/5] END max_depth=7, min_samples_leaf=1, min_samples_split=2;, score=0.951 total time=   0.0s
# [CV 3/5] END max_depth=7, min_samples_leaf=1, min_samples_split=2;, score=0.725 total time=   0.0s
# [CV 4/5] END max_depth=7, min_samples_leaf=1, min_samples_split=2;, score=0.885 total time=   0.0s
# [CV 5/5] END max_depth=7, min_samples_leaf=1, min_samples_split=2;, score=0.957 total time=   0.0s
# [CV 1/5] END max_depth=7, min_samples_leaf=1, min_samples_split=5;, score=0.954 total time=   0.0s
# [CV 2/5] END max_depth=7, min_samples_leaf=1, min_samples_split=5;, score=0.951 total time=   0.0s
# [CV 3/5] END max_depth=7, min_samples_leaf=1, min_samples_split=5;, score=0.708 total time=   0.0s
# [CV 4/5] END max_depth=7, min_samples_leaf=1, min_samples_split=5;, score=0.958 total time=   0.0s
# [CV 5/5] END max_depth=7, min_samples_leaf=1, min_samples_split=5;, score=0.957 total time=   0.0s
# [CV 1/5] END max_depth=7, min_samples_leaf=1, min_samples_split=10;, score=0.958 total time=   0.0s
# [CV 2/5] END max_depth=7, min_samples_leaf=1, min_samples_split=10;, score=0.952 total time=   0.0s
# [CV 3/5] END max_depth=7, min_samples_leaf=1, min_samples_split=10;, score=0.711 total time=   0.0s
# [CV 4/5] END max_depth=7, min_samples_leaf=1, min_samples_split=10;, score=0.959 total time=   0.0s
# [CV 5/5] END max_depth=7, min_samples_leaf=1, min_samples_split=10;, score=0.955 total time=   0.0s
# [CV 1/5] END max_depth=7, min_samples_leaf=3, min_samples_split=2;, score=0.949 total time=   0.0s
# [CV 2/5] END max_depth=7, min_samples_leaf=3, min_samples_split=2;, score=0.953 total time=   0.0s
# [CV 3/5] END max_depth=7, min_samples_leaf=3, min_samples_split=2;, score=0.709 total time=   0.0s
# [CV 4/5] END max_depth=7, min_samples_leaf=3, min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 5/5] END max_depth=7, min_samples_leaf=3, min_samples_split=2;, score=0.940 total time=   0.0s
# [CV 1/5] END max_depth=7, min_samples_leaf=3, min_samples_split=5;, score=0.949 total time=   0.0s
# [CV 2/5] END max_depth=7, min_samples_leaf=3, min_samples_split=5;, score=0.953 total time=   0.0s
# [CV 3/5] END max_depth=7, min_samples_leaf=3, min_samples_split=5;, score=0.709 total time=   0.0s
# [CV 4/5] END max_depth=7, min_samples_leaf=3, min_samples_split=5;, score=0.708 total time=   0.0s
# [CV 5/5] END max_depth=7, min_samples_leaf=3, min_samples_split=5;, score=0.940 total time=   0.0s
# [CV 1/5] END max_depth=7, min_samples_leaf=3, min_samples_split=10;, score=0.956 total time=   0.0s
# [CV 2/5] END max_depth=7, min_samples_leaf=3, min_samples_split=10;, score=0.952 total time=   0.0s
# [CV 3/5] END max_depth=7, min_samples_leaf=3, min_samples_split=10;, score=0.709 total time=   0.0s
# [CV 4/5] END max_depth=7, min_samples_leaf=3, min_samples_split=10;, score=0.680 total time=   0.0s
# [CV 5/5] END max_depth=7, min_samples_leaf=3, min_samples_split=10;, score=0.955 total time=   0.0s
# [CV 1/5] END max_depth=7, min_samples_leaf=10, min_samples_split=2;, score=0.772 total time=   0.0s
# [CV 2/5] END max_depth=7, min_samples_leaf=10, min_samples_split=2;, score=0.753 total time=   0.0s
# [CV 3/5] END max_depth=7, min_samples_leaf=10, min_samples_split=2;, score=0.912 total time=   0.0s
# [CV 4/5] END max_depth=7, min_samples_leaf=10, min_samples_split=2;, score=0.676 total time=   0.0s
# [CV 5/5] END max_depth=7, min_samples_leaf=10, min_samples_split=2;, score=0.862 total time=   0.0s
# [CV 1/5] END max_depth=7, min_samples_leaf=10, min_samples_split=5;, score=0.772 total time=   0.0s
# [CV 2/5] END max_depth=7, min_samples_leaf=10, min_samples_split=5;, score=0.753 total time=   0.0s
# [CV 3/5] END max_depth=7, min_samples_leaf=10, min_samples_split=5;, score=0.912 total time=   0.0s
# [CV 4/5] END max_depth=7, min_samples_leaf=10, min_samples_split=5;, score=0.676 total time=   0.0s
# [CV 5/5] END max_depth=7, min_samples_leaf=10, min_samples_split=5;, score=0.862 total time=   0.0s
# [CV 1/5] END max_depth=7, min_samples_leaf=10, min_samples_split=10;, score=0.772 total time=   0.0s
# [CV 2/5] END max_depth=7, min_samples_leaf=10, min_samples_split=10;, score=0.753 total time=   0.0s
# [CV 3/5] END max_depth=7, min_samples_leaf=10, min_samples_split=10;, score=0.912 total time=   0.0s
# [CV 4/5] END max_depth=7, min_samples_leaf=10, min_samples_split=10;, score=0.676 total time=   0.0s
# [CV 5/5] END max_depth=7, min_samples_leaf=10, min_samples_split=10;, score=0.862 total time=   0.0s
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.9260883176737718

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score,mean_squared_error

# %% [markdown]
# ## Train Test Split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_revenue,y_revenue,test_size=0.3,random_state=2022)

s=StandardScaler()
X_train_scaled = s.fit_transform(X_train)
X_test_scaled = s.transform(X_test)

# %%
Accuracy_Scores = []

# %% [markdown]
# ## K Nearest Neighbors

# %% [markdown]
# ###Using accuracy score

# %%
scores=[]
for k in range(1,30):
    knn=KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train_scaled,y_train)
    #print('Executing for k =',k)
    y_pred1=knn.predict(X_test_scaled)
    scores.append(r2_score(y_test,y_pred1))

kmax_i=np.argmax(scores)

print('Max accuracy:',scores[kmax_i],'for k =',kmax_i+1)
# Out:
# Max accuracy: 0.8650387882570747 for k = 2

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,30),scores,color='blue', linestyle='dashed', marker='o',markerfacecolor='red', markersize=10)
plt.title('r2 score vs. K Value')
plt.xlabel('K')
plt.ylabel('r2 score')
plt.xticks(range(1,30))
plt.grid()
plt.show()

# %%
error_rate=[]
for k in range(1,30):
    knn=KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train_scaled,y_train)
    #print('Executing for k=',k)
    y_pred1=knn.predict(X_test_scaled)
    error_rate.append(mean_squared_error(y_pred1, y_test))

kmin_i=np.argmin(scores)

# %%
plt.figure(figsize=(15,6))
plt.plot(range(1,30),error_rate,color='blue', linestyle='dashed', marker='o',markerfacecolor='red', markersize=10)
plt.title('error rate vs. K Value')
plt.xlabel('K')
plt.ylabel('error rate')
plt.xticks(range(1,30))
plt.grid()
plt.show()

# %% [markdown]
# After k = 2, r2 score is descreasing rapidly and error is increased. So we select k=2.

# %%
knn=KNeighborsRegressor(n_neighbors=3)
knn.fit(X_train_scaled,y_train)
y_pred1=knn.predict(X_test_scaled)
print('r2 score : ',r2_score(y_test,y_pred1))
# Out:
# r2 score :  0.8450578330169121

# %%
Accuracy_Scores.append(r2_score(y_test,y_pred1))

# %% [markdown]
# ###**r2 with GridSearchCV**

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

knn=KNeighborsRegressor()
scaler=StandardScaler()

params={'n_neighbors':np.arange(1,30)}
kfold=KFold(n_splits=5,shuffle=True,random_state=2022)
gcv=GridSearchCV(knn, param_grid=params,scoring='r2',cv=kfold,verbose=3)
gcv.fit(X_train_scaled,y_train)
print('Using KNN : ')
print('k = ',gcv.best_params_)
print('best score = ',gcv.best_score_)
# Out:
# Fitting 5 folds for each of 29 candidates, totalling 145 fits
# [CV 1/5] END .....................n_neighbors=1;, score=0.782 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=1;, score=0.611 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=1;, score=0.770 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=1;, score=0.635 total time=   0.0s
# [CV 3/5] END ..................n_neighbors=24;, score=-29.549 total time=   0.0s
# [CV 4/5] END ..................n_neighbors=24;, score=-30.470 total time=   0.0s
# [CV 5/5] END ..................n_neighbors=24;, score=-29.954 total time=   0.0s
# [CV 1/5] END ..................n_neighbors=25;, score=-29.180 total time=   0.0s
# [CV 2/5] END ..................n_neighbors=25;, score=-34.370 total time=   0.0s
# [CV 3/5] END ..................n_neighbors=25;, score=-29.683 total time=   0.0s
# [CV 4/5] END ..................n_neighbors=25;, score=-30.455 total time=   0.0s
# [CV 5/5] END ..................n_neighbors=25;, score=-30.087 total time=   0.0s
# [CV 1/5] END ..................n_neighbors=26;, score=-29.389 total time=   0.0s
# [CV 2/5] END ..................n_neighbors=26;, score=-34.467 total time=   0.0s
# [CV 3/5] END ..................n_neighbors=26;, score=-29.871 total time=   0.0s
# [CV 4/5] END ..................n_neighbors=26;, score=-30.575 total time=   0.0s
# [CV 5/5] END ..................n_neighbors=26;, score=-30.127 total time=   0.0s
# [CV 1/5] END ..................n_neighbors=27;, score=-29.633 total time=   0.0s
# [CV 2/5] END ..................n_neighbors=27;, score=-34.705 total time=   0.0s
# [CV 3/5] END ..................n_neighbors=27;, score=-30.048 total time=   0.0s
# [CV 4/5] END ..................n_neighbors=27;, score=-30.602 total time=   0.0s
# [CV 5/5] END ..................n_neighbors=27;, score=-30.259 total time=   0.0s
# [CV 1/5] END ..................n_neighbors=28;, score=-29.841 total time=   0.0s
# [CV 2/5] END ..................n_neighbors=28;, score=-34.865 total time=   0.0s
# [CV 3/5] END ..................n_neighbors=28;, score=-30.180 total time=   0.0s
# [CV 4/5] END ..................n_neighbors=28;, score=-30.750 total time=   0.0s
# [CV 5/5] END ..................n_neighbors=28;, score=-30.391 total time=   0.0s
# [CV 1/5] END ..................n_neighbors=29;, score=-30.038 total time=   0.0s
# [CV 2/5] END ..................n_neighbors=29;, score=-35.165 total time=   0.0s
# [CV 3/5] END ..................n_neighbors=29;, score=-30.241 total time=   0.0s
# [CV 4/5] END ..................n_neighbors=29;, score=-30.943 total time=   0.0s
# [CV 5/5] END ..................n_neighbors=29;, score=-30.508 total time=   0.0s
# Using KNN :
# k =  {'n_neighbors': 4}
# best score =  -26.347591562524844

# %%
best_model = gcv.best_estimator_
best_model
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
from sklearn.metrics import mean_absolute_error
y_pred1=best_model.predict(X_test_scaled)
print('MAE : ',mean_absolute_error(y_test,y_pred1))
# Out:
# MAE :  26.624284167725104

# %%
plt.scatter(y_test, y_pred1,c = 'green')
plt.plot([0, 50], [0, 50], '--k')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title("Actual Value vs Predicted Value :KNN")
plt.show()

# %% [markdown]
# ## **SVR**

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
## Linear Kernel

svm_l = SVR(kernel='linear')
params = {'C':np.linspace(0.001,3,5),
          'epsilon':np.linspace(0.001,3,5)}
gcv_svm = GridSearchCV(svm_l, param_grid=params,scoring='r2',cv=kfold,verbose=3)

gcv_svm.fit(X_train_scaled,y_train)

print('Best params: ',gcv_svm.best_params_)               
print('Best score: ',gcv_svm.best_score_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [C
# [CV 2/5] END ..............C=3.0, epsilon=0.001;, score=0.757 total time=   0.7s
# [CV 3/5] END ..............C=3.0, epsilon=0.001;, score=0.810 total time=   0.6s
# [CV 4/5] END ..............C=3.0, epsilon=0.001;, score=0.763 total time=   0.7s
# [CV 5/5] END ..............C=3.0, epsilon=0.001;, score=0.782 total time=   0.6s
# [CV 1/5] END ............C=3.0, epsilon=0.75075;, score=0.811 total time=   0.7s
# [CV 2/5] END ............C=3.0, epsilon=0.75075;, score=0.756 total time=   0.6s
# [CV 3/5] END ............C=3.0, epsilon=0.75075;, score=0.809 total time=   0.6s
# [CV 4/5] END ............C=3.0, epsilon=0.75075;, score=0.763 total time=   0.6s
# [CV 5/5] END ............C=3.0, epsilon=0.75075;, score=0.782 total time=   1.0s
# [CV 1/5] END .............C=3.0, epsilon=1.5005;, score=0.811 total time=   1.1s
# [CV 2/5] END .............C=3.0, epsilon=1.5005;, score=0.758 total time=   1.0s
# [CV 3/5] END .............C=3.0, epsilon=1.5005;, score=0.809 total time=   0.6s
# [CV 4/5] END .............C=3.0, epsilon=1.5005;, score=0.765 total time=   0.6s
# [CV 5/5] END .............C=3.0, epsilon=1.5005;, score=0.783 total time=   0.6s
# [CV 1/5] END ............C=3.0, epsilon=2.25025;, score=0.812 total time=   0.6s
# [CV 2/5] END ............C=3.0, epsilon=2.25025;, score=0.757 total time=   0.6s
# [CV 3/5] END ............C=3.0, epsilon=2.25025;, score=0.810 total time=   0.6s
# [CV 4/5] END ............C=3.0, epsilon=2.25025;, score=0.764 total time=   0.6s
# [CV 5/5] END ............C=3.0, epsilon=2.25025;, score=0.783 total time=   0.6s
# [CV 1/5] END ................C=3.0, epsilon=3.0;, score=0.813 total time=   0.6s
# [CV 2/5] END ................C=3.0, epsilon=3.0;, score=0.757 total time=   0.6s
# [CV 3/5] END ................C=3.0, epsilon=3.0;, score=0.810 total time=   0.6s
# [CV 4/5] END ................C=3.0, epsilon=3.0;, score=0.763 total time=   0.6s
# [CV 5/5] END ................C=3.0, epsilon=3.0;, score=0.783 total time=   0.6s
# Best params:  {'C': 3.0, 'epsilon': 3.0}
# Best score:  0.7852993518404301

# %% [markdown]
# It takes 1m 31s to execute

# %%
###predicting on test data
y_pred2 = gcv_svm.predict(X_test_scaled)

print('R2 score: ',r2_score(y_test,y_pred2))
# Out:
# R2 score:  0.7741136889359705

# %%
Accuracy_Scores.append(r2_score(y_test,y_pred2))

# %%
svm_r = SVR()
params = {'C':np.linspace(0.001,3,5),
          'epsilon':np.linspace(0.001,3,5)}
gcv_svm_r = GridSearchCV(svm_r, param_grid=params,scoring='r2',cv=kfold,verbose=3)

gcv_svm_r.fit(X_train_scaled,y_train)

print('Best params: ',gcv_svm_r.best_params_)               
print('Best score: ',gcv_svm_r.best_score_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [C
# [CV 1/5] END ............C=3.0, epsilon=0.75075;, score=0.547 total time=   0.7s
# [CV 2/5] END ............C=3.0, epsilon=0.75075;, score=0.232 total time=   0.7s
# [CV 3/5] END ............C=3.0, epsilon=0.75075;, score=0.622 total time=   0.6s
# [CV 4/5] END ............C=3.0, epsilon=0.75075;, score=0.383 total time=   0.7s
# [CV 5/5] END ............C=3.0, epsilon=0.75075;, score=0.690 total time=   0.7s
# [CV 1/5] END .............C=3.0, epsilon=1.5005;, score=0.547 total time=   0.6s
# [CV 2/5] END .............C=3.0, epsilon=1.5005;, score=0.232 total time=   0.9s
# [CV 3/5] END .............C=3.0, epsilon=1.5005;, score=0.622 total time=   1.0s
# [CV 4/5] END .............C=3.0, epsilon=1.5005;, score=0.383 total time=   1.0s
# [CV 5/5] END .............C=3.0, epsilon=1.5005;, score=0.690 total time=   0.7s
# [CV 1/5] END ............C=3.0, epsilon=2.25025;, score=0.547 total time=   0.6s
# [CV 2/5] END ............C=3.0, epsilon=2.25025;, score=0.232 total time=   0.6s
# [CV 3/5] END ............C=3.0, epsilon=2.25025;, score=0.622 total time=   0.6s
# [CV 4/5] END ............C=3.0, epsilon=2.25025;, score=0.384 total time=   0.6s
# [CV 5/5] END ............C=3.0, epsilon=2.25025;, score=0.690 total time=   0.6s
# [CV 1/5] END ................C=3.0, epsilon=3.0;, score=0.548 total time=   0.5s
# [CV 2/5] END ................C=3.0, epsilon=3.0;, score=0.232 total time=   0.5s
# [CV 3/5] END ................C=3.0, epsilon=3.0;, score=0.622 total time=   0.5s
# [CV 4/5] END ................C=3.0, epsilon=3.0;, score=0.384 total time=   0.5s
# [CV 5/5] END ................C=3.0, epsilon=3.0;, score=0.689 total time=   0.5s
# Best params:  {'C': 3.0, 'epsilon': 3.0}
# Best score:  0.4949102276874262

# %%
###predicting on test data
y_pred2 = gcv_svm_r.predict(X_test_scaled)

print('R2 score: ',r2_score(y_test,y_pred2))
# Out:
# R2 score:  0.4401964023615146

# %% [markdown]
# ## **XGBRegressor**

# %%
model_xgb=XGBRegressor(random_state=2022)
params={'max_depth':[2,3,4,5,6],'n_estimators':[50,100],'learning_rate':[0.01,0.3,0.05,0.5,0.7]}
gcv_xgb=GridSearchCV(model_xgb,scoring='r2',param_grid=params,cv=kfold,verbose=3)
gcv_xgb.fit(X_train_scaled,y_train)
print('Best score  : ',gcv_xgb.best_score_)
print('Best params  : ',gcv_xgb.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=0.028 total time=   0.8s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=0.075 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=-0.044 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=0.136 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=0.008 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.403 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.308 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.382 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.437 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.422 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.169 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.174 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.104 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.238 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.153 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.560 total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.436 total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.553 total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.541 total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.597 total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=4, n_estimators=50;, score=0.251 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=4, n_estimators=50;, score=0.218 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=4, n_estimators=50;, score=0.213 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=4, n_estimators=50;, score=0.280 total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=4, n_estimators=50;, score=0.221 total time=   0.5s
# [CV 1/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=0.649 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=0.495 total time=   0.4s
# [CV 3/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=0.652 total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=0.585 total time=   2.3s
# [CV 5/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=0.669 total time=   1.3s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.272 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.221 total time=   2.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.228 total time=   3.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.283 total time=   3.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.243 total time=   2.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.672 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.498 total time=   0.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.670 total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.590 total time=   0.4s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.697 total time=   0.5s
# [CV 1/5] END learning_rate=0.01, max_depth=6, n_estimators=50;, score=0.280 total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=6, n_estimators=50;, score=0.222 total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=6, n_estimators=50;, score=0.239 total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=6, n_estimators=50;, score=0.283 total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=6, n_estimators=50;, score=0.251 total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=0.679 total time=   0.6s
# [CV 2/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=0.498 total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=0.675 total time=   0.6s
# [CV 4/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=0.590 total time=   0.6s
# [CV 5/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=0.704 total time=   0.6s
# [CV 1/5] END learning_rate=0.3, max_depth=2, n_estimators=50;, score=0.974 total time=   0.1s
# [CV 2/5] END learning_rate=0.3, max_depth=2, n_estimators=50;, score=0.889 total time=   0.1s
# [CV 3/5] END learning_rate=0.3, max_depth=2, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 4/5] END learning_rate=0.3, max_depth=2, n_estimators=50;, score=0.876 total time=   0.1s
# [CV 5/5] END learning_rate=0.3, max_depth=2, n_estimators=50;, score=0.960 total time=   0.1s
# [CV 1/5] END learning_rate=0.3, max_depth=2, n_estimators=100;, score=0.983 total time=   0.2s
# [CV 2/5] END learning_rate=0.3, max_depth=2, n_estimators=100;, score=0.892 total time=   0.2s
# [CV 3/5] END learning_rate=0.3, max_depth=2, n_estimators=100;, score=0.967 total time=   0.2s
# [CV 4/5] END learning_rate=0.3, max_depth=2, n_estimators=100;, score=0.880 total time=   0.2s
# [CV 5/5] END learning_rate=0.3, max_depth=2, n_estimators=100;, score=0.977 total time=   0.2s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.984 total time=   0.1s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.892 total time=   0.2s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.974 total time=   0.1s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.913 total time=   0.1s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.980 total time=   0.1s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.987 total time=   0.3s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.893 total time=   0.3s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.978 total time=   0.3s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.914 total time=   0.3s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.982 total time=   2.2s
# [CV 1/5] END learning_rate=0.3, max_depth=4, n_estimators=50;, score=0.986 total time=   0.2s
# [CV 2/5] END learning_rate=0.3, max_depth=4, n_estimators=50;, score=0.904 total time=   0.2s
# [CV 3/5] END learning_rate=0.3, max_depth=4, n_estimators=50;, score=0.977 total time=   0.2s
# [CV 4/5] END learning_rate=0.3, max_depth=4, n_estimators=50;, score=0.856 total time=   0.2s
# [CV 5/5] END learning_rate=0.3, max_depth=4, n_estimators=50;, score=0.985 total time=   0.2s
# [CV 1/5] END learning_rate=0.3, max_depth=4, n_estimators=100;, score=0.986 total time=   0.4s
# [CV 2/5] END learning_rate=0.3, max_depth=4, n_estimators=100;, score=0.905 total time=   0.4s
# [CV 3/5] END learning_rate=0.3, max_depth=4, n_estimators=100;, score=0.980 total time=   0.3s
# [CV 4/5] END learning_rate=0.3, max_depth=4, n_estimators=100;, score=0.858 total time=   0.4s
# [CV 5/5] END learning_rate=0.3, max_depth=4, n_estimators=100;, score=0.986 total time=   0.4s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.984 total time=   0.2s
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.906 total time=   0.2s
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.974 total time=   0.3s
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.859 total time=   0.2s
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.989 total time=   0.2s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.984 total time=   0.5s
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.906 total time=   0.5s
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.975 total time=   0.5s
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.859 total time=   0.5s
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.990 total time=   0.5s
# [CV 1/5] END learning_rate=0.3, max_depth=6, n_estimators=50;, score=0.982 total time=   0.3s
# [CV 2/5] END learning_rate=0.3, max_depth=6, n_estimators=50;, score=0.906 total time=   0.3s
# [CV 3/5] END learning_rate=0.3, max_depth=6, n_estimators=50;, score=0.962 total time=   0.3s
# [CV 4/5] END learning_rate=0.3, max_depth=6, n_estimators=50;, score=0.873 total time=   0.3s
# [CV 5/5] END learning_rate=0.3, max_depth=6, n_estimators=50;, score=0.987 total time=   0.3s
# [CV 1/5] END learning_rate=0.3, max_depth=6, n_estimators=100;, score=0.983 total time=   0.6s
# [CV 2/5] END learning_rate=0.3, max_depth=6, n_estimators=100;, score=0.907 total time=   0.6s
# [CV 3/5] END learning_rate=0.3, max_depth=6, n_estimators=100;, score=0.962 total time=   0.6s
# [CV 4/5] END learning_rate=0.3, max_depth=6, n_estimators=100;, score=0.874 total time=   0.6s
# [CV 5/5] END learning_rate=0.3, max_depth=6, n_estimators=100;, score=0.987 total time=   2.4s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.789 total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.644 total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.788 total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.721 total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.796 total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.899 total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.818 total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.898 total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.819 total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.891 total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.900 total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.759 total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.909 total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.809 total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.919 total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.968 total time=   0.3s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.873 total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.967 total time=   0.3s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.870 total time=   0.3s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.971 total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=4, n_estimators=50;, score=0.939 total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=4, n_estimators=50;, score=0.785 total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=4, n_estimators=50;, score=0.943 total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=4, n_estimators=50;, score=0.823 total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=4, n_estimators=50;, score=0.955 total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=4, n_estimators=100;, score=0.979 total time=   0.3s
# [CV 2/5] END learning_rate=0.05, max_depth=4, n_estimators=100;, score=0.879 total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=4, n_estimators=100;, score=0.977 total time=   0.4s
# [CV 4/5] END learning_rate=0.05, max_depth=4, n_estimators=100;, score=0.882 total time=   0.3s
# [CV 5/5] END learning_rate=0.05, max_depth=4, n_estimators=100;, score=0.986 total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.950 total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.787 total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.950 total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.824 total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.969 total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.980 total time=   0.5s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.881 total time=   0.4s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.975 total time=   0.5s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.876 total time=   0.4s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.990 total time=   0.6s
# [CV 1/5] END learning_rate=0.05, max_depth=6, n_estimators=50;, score=0.953 total time=   2.0s
# [CV 2/5] END learning_rate=0.05, max_depth=6, n_estimators=50;, score=0.788 total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=6, n_estimators=50;, score=0.952 total time=   0.3s
# [CV 4/5] END learning_rate=0.05, max_depth=6, n_estimators=50;, score=0.823 total time=   0.3s
# [CV 5/5] END learning_rate=0.05, max_depth=6, n_estimators=50;, score=0.972 total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=0.981 total time=   0.5s
# [CV 2/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=0.881 total time=   0.6s
# [CV 3/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=0.972 total time=   0.5s
# [CV 4/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=0.875 total time=   0.6s
# [CV 5/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=0.990 total time=   0.5s
# [CV 1/5] END learning_rate=0.5, max_depth=2, n_estimators=50;, score=0.973 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=2, n_estimators=50;, score=0.894 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, max_depth=2, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, max_depth=2, n_estimators=50;, score=0.919 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, max_depth=2, n_estimators=50;, score=0.973 total time=   0.1s
# [CV 1/5] END learning_rate=0.5, max_depth=2, n_estimators=100;, score=0.980 total time=   0.2s
# [CV 2/5] END learning_rate=0.5, max_depth=2, n_estimators=100;, score=0.897 total time=   0.2s
# [CV 3/5] END learning_rate=0.5, max_depth=2, n_estimators=100;, score=0.961 total time=   0.2s
# [CV 4/5] END learning_rate=0.5, max_depth=2, n_estimators=100;, score=0.929 total time=   0.2s
# [CV 5/5] END learning_rate=0.5, max_depth=2, n_estimators=100;, score=0.978 total time=   0.2s
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.982 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.886 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.960 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.884 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.980 total time=   0.1s
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=0.985 total time=   0.3s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=0.886 total time=   0.3s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=0.962 total time=   0.3s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=0.884 total time=   0.3s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=0.981 total time=   0.3s
# [CV 1/5] END learning_rate=0.5, max_depth=4, n_estimators=50;, score=0.982 total time=   0.2s
# [CV 2/5] END learning_rate=0.5, max_depth=4, n_estimators=50;, score=0.902 total time=   0.2s
# [CV 3/5] END learning_rate=0.5, max_depth=4, n_estimators=50;, score=0.975 total time=   0.2s
# [CV 4/5] END learning_rate=0.5, max_depth=4, n_estimators=50;, score=0.888 total time=   0.2s
# [CV 5/5] END learning_rate=0.5, max_depth=4, n_estimators=50;, score=0.983 total time=   0.2s
# [CV 1/5] END learning_rate=0.5, max_depth=4, n_estimators=100;, score=0.983 total time=   0.3s
# [CV 2/5] END learning_rate=0.5, max_depth=4, n_estimators=100;, score=0.902 total time=   0.4s
# [CV 3/5] END learning_rate=0.5, max_depth=4, n_estimators=100;, score=0.976 total time=   0.4s
# [CV 4/5] END learning_rate=0.5, max_depth=4, n_estimators=100;, score=0.890 total time=   0.4s
# [CV 5/5] END learning_rate=0.5, max_depth=4, n_estimators=100;, score=0.983 total time=   2.2s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.982 total time=   0.2s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.901 total time=   0.2s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.970 total time=   0.2s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.886 total time=   0.2s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.984 total time=   0.2s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.983 total time=   0.5s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.901 total time=   0.5s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.971 total time=   0.5s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.886 total time=   0.5s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.984 total time=   0.5s
# [CV 1/5] END learning_rate=0.5, max_depth=6, n_estimators=50;, score=0.980 total time=   0.3s
# [CV 2/5] END learning_rate=0.5, max_depth=6, n_estimators=50;, score=0.906 total time=   0.3s
# [CV 3/5] END learning_rate=0.5, max_depth=6, n_estimators=50;, score=0.956 total time=   0.3s
# [CV 4/5] END learning_rate=0.5, max_depth=6, n_estimators=50;, score=0.880 total time=   0.3s
# [CV 5/5] END learning_rate=0.5, max_depth=6, n_estimators=50;, score=0.986 total time=   0.3s
# [CV 1/5] END learning_rate=0.5, max_depth=6, n_estimators=100;, score=0.980 total time=   0.6s
# [CV 2/5] END learning_rate=0.5, max_depth=6, n_estimators=100;, score=0.906 total time=   0.6s
# [CV 3/5] END learning_rate=0.5, max_depth=6, n_estimators=100;, score=0.956 total time=   0.6s
# [CV 4/5] END learning_rate=0.5, max_depth=6, n_estimators=100;, score=0.880 total time=   0.5s
# [CV 5/5] END learning_rate=0.5, max_depth=6, n_estimators=100;, score=0.986 total time=   0.6s
# [CV 1/5] END learning_rate=0.7, max_depth=2, n_estimators=50;, score=0.967 total time=   0.1s
# [CV 2/5] END learning_rate=0.7, max_depth=2, n_estimators=50;, score=0.878 total time=   0.1s
# [CV 3/5] END learning_rate=0.7, max_depth=2, n_estimators=50;, score=0.958 total time=   0.1s
# [CV 4/5] END learning_rate=0.7, max_depth=2, n_estimators=50;, score=0.910 total time=   0.1s
# [CV 5/5] END learning_rate=0.7, max_depth=2, n_estimators=50;, score=0.969 total time=   0.1s
# [CV 1/5] END learning_rate=0.7, max_depth=2, n_estimators=100;, score=0.974 total time=   0.2s
# [CV 2/5] END learning_rate=0.7, max_depth=2, n_estimators=100;, score=0.880 total time=   0.2s
# [CV 3/5] END learning_rate=0.7, max_depth=2, n_estimators=100;, score=0.963 total time=   0.2s
# [CV 4/5] END learning_rate=0.7, max_depth=2, n_estimators=100;, score=0.904 total time=   0.2s
# [CV 5/5] END learning_rate=0.7, max_depth=2, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 1/5] END learning_rate=0.7, max_depth=3, n_estimators=50;, score=0.981 total time=   0.2s
# [CV 2/5] END learning_rate=0.7, max_depth=3, n_estimators=50;, score=0.881 total time=   0.2s
# [CV 3/5] END learning_rate=0.7, max_depth=3, n_estimators=50;, score=0.960 total time=   0.1s
# [CV 4/5] END learning_rate=0.7, max_depth=3, n_estimators=50;, score=0.888 total time=   1.8s
# [CV 5/5] END learning_rate=0.7, max_depth=3, n_estimators=50;, score=0.978 total time=   0.3s
# [CV 1/5] END learning_rate=0.7, max_depth=3, n_estimators=100;, score=0.982 total time=   0.3s
# [CV 2/5] END learning_rate=0.7, max_depth=3, n_estimators=100;, score=0.880 total time=   0.3s
# [CV 3/5] END learning_rate=0.7, max_depth=3, n_estimators=100;, score=0.961 total time=   0.3s
# [CV 4/5] END learning_rate=0.7, max_depth=3, n_estimators=100;, score=0.890 total time=   0.3s
# [CV 5/5] END learning_rate=0.7, max_depth=3, n_estimators=100;, score=0.977 total time=   0.3s
# [CV 1/5] END learning_rate=0.7, max_depth=4, n_estimators=50;, score=0.980 total time=   0.2s
# [CV 2/5] END learning_rate=0.7, max_depth=4, n_estimators=50;, score=0.908 total time=   0.2s
# [CV 3/5] END learning_rate=0.7, max_depth=4, n_estimators=50;, score=0.969 total time=   0.2s
# [CV 4/5] END learning_rate=0.7, max_depth=4, n_estimators=50;, score=0.930 total time=   0.2s
# [CV 5/5] END learning_rate=0.7, max_depth=4, n_estimators=50;, score=0.978 total time=   0.2s
# [CV 1/5] END learning_rate=0.7, max_depth=4, n_estimators=100;, score=0.980 total time=   0.3s
# [CV 2/5] END learning_rate=0.7, max_depth=4, n_estimators=100;, score=0.908 total time=   0.4s
# [CV 3/5] END learning_rate=0.7, max_depth=4, n_estimators=100;, score=0.969 total time=   0.4s
# [CV 4/5] END learning_rate=0.7, max_depth=4, n_estimators=100;, score=0.930 total time=   0.4s
# [CV 5/5] END learning_rate=0.7, max_depth=4, n_estimators=100;, score=0.979 total time=   0.4s
# [CV 1/5] END learning_rate=0.7, max_depth=5, n_estimators=50;, score=0.975 total time=   0.2s
# [CV 2/5] END learning_rate=0.7, max_depth=5, n_estimators=50;, score=0.901 total time=   0.2s
# [CV 3/5] END learning_rate=0.7, max_depth=5, n_estimators=50;, score=0.956 total time=   0.3s
# [CV 4/5] END learning_rate=0.7, max_depth=5, n_estimators=50;, score=0.920 total time=   0.2s
# [CV 5/5] END learning_rate=0.7, max_depth=5, n_estimators=50;, score=0.975 total time=   0.2s
# [CV 1/5] END learning_rate=0.7, max_depth=5, n_estimators=100;, score=0.975 total time=   0.5s
# [CV 2/5] END learning_rate=0.7, max_depth=5, n_estimators=100;, score=0.901 total time=   0.5s
# [CV 3/5] END learning_rate=0.7, max_depth=5, n_estimators=100;, score=0.957 total time=   0.5s
# [CV 4/5] END learning_rate=0.7, max_depth=5, n_estimators=100;, score=0.920 total time=   0.5s
# [CV 5/5] END learning_rate=0.7, max_depth=5, n_estimators=100;, score=0.974 total time=   0.5s
# [CV 1/5] END learning_rate=0.7, max_depth=6, n_estimators=50;, score=0.975 total time=   0.3s
# [CV 2/5] END learning_rate=0.7, max_depth=6, n_estimators=50;, score=0.905 total time=   0.3s
# [CV 3/5] END learning_rate=0.7, max_depth=6, n_estimators=50;, score=0.933 total time=   0.3s
# [CV 4/5] END learning_rate=0.7, max_depth=6, n_estimators=50;, score=0.887 total time=   0.3s
# [CV 5/5] END learning_rate=0.7, max_depth=6, n_estimators=50;, score=0.981 total time=   0.3s
# [CV 1/5] END learning_rate=0.7, max_depth=6, n_estimators=100;, score=0.974 total time=   0.6s
# [CV 2/5] END learning_rate=0.7, max_depth=6, n_estimators=100;, score=0.904 total time=   2.5s
# [CV 3/5] END learning_rate=0.7, max_depth=6, n_estimators=100;, score=0.933 total time=   0.6s
# [CV 4/5] END learning_rate=0.7, max_depth=6, n_estimators=100;, score=0.887 total time=   0.6s
# [CV 5/5] END learning_rate=0.7, max_depth=6, n_estimators=100;, score=0.981 total time=   0.6s
# Best score  :  0.9533370163825537
# Best params  :  {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 100}

# %% [markdown]
# It takes 1m 58s to execute

# %%
y_pred3 = gcv_xgb.predict(X_test_scaled)

print('R2 score: ',r2_score(y_test,y_pred3))
# Out:
# R2 score:  0.9331231712457421

# %%
Accuracy_Scores.append(r2_score(y_test,y_pred3))

# %%
plt.scatter(y_test, y_pred3,c = 'green')
plt.plot([0, 50], [0, 50], '--k')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title("Actual Value vs Predicted Value:Linear Regression")
plt.show()

# %%
# Create a residual plot
residuals = y_test - y_pred3
plt.scatter(y_pred3, residuals)
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# ## **Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_rf=RandomForestRegressor(random_state=2022)
params={'max_features':[4,5,6],'max_depth':[3, 5, 7],'min_samples_split':[2, 5, 10],'min_samples_leaf':[1, 3, 10]}
gcv_rf = GridSearchCV(estimator=model_rf, param_grid=params,scoring='r2',cv=kfold,verbose=3)
gcv_rf.fit(X_train_scaled,y_train)
print('Best parameters : ',gcv_rf.best_params_)
print('Best score : ',gcv_rf.best_score_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.687 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.554 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.629 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.490 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.662 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.689 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.554 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.632 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.491 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.662 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.689 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.552 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.632 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.489 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.662 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.716 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.484 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.664 total time=   1.0s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.664 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.668 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.716 total time=   0.9s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.484 total time=   0.9s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.664 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.664 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.668 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.716 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.484 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.664 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.663 total time=   0.7s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.668 total time=   0.9s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.708 total time=   0.7s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.393 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.738 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.535 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.714 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.708 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.393 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.738 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.535 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.714 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.708 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.393 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.738 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.535 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.714 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.710 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.607 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.657 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.522 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.688 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.709 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.606 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.657 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.523 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.688 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.709 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.605 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.656 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.523 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.688 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.749 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.525 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.689 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.722 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.703 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.749 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.525 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.689 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.722 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.703 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.749 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.524 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.689 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.722 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.704 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.756 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.418 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.757 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.567 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.743 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.756 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.418 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.757 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.567 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.743 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.756 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.418 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.757 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.567 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.743 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.755 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.650 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.714 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.552 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.747 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.755 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.636 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.711 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.552 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.747 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.755 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.636 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.711 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.551 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.747 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.778 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.548 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.745 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.741 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.754 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.778 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.548 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.745 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.741 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.754 total time=   1.1s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.778 total time=   0.7s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.548 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.745 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.739 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.754 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.789 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.454 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.799 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.607 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.795 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.789 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.454 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.799 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.607 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.795 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.789 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.454 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.799 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.607 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.795 total time=   0.3s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.853 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.659 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.834 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.637 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.837 total time=   0.3s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.855 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.646 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.837 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.644 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.839 total time=   0.3s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.852 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.641 total time=   0.3s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.839 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.643 total time=   0.5s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.838 total time=   0.5s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.867 total time=   0.5s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.566 total time=   0.5s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.849 total time=   0.6s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.737 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.840 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.867 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.566 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.849 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.737 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.840 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.865 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.560 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.848 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.742 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.839 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.839 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.464 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.878 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.619 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.835 total time=   0.3s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.839 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.464 total time=   0.3s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.878 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.619 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.835 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.839 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.464 total time=   0.3s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.878 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.619 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.835 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.894 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.714 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.875 total time=   0.6s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.694 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.878 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.892 total time=   0.6s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.700 total time=   0.5s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.876 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.698 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.875 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.895 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.703 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.876 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.680 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.877 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.898 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.607 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.884 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.817 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.892 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.898 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.607 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.884 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.817 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.892 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.903 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.604 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.886 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.819 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.893 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.880 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.493 total time=   0.5s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.905 total time=   0.6s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.668 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.884 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.880 total time=   0.6s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.493 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.905 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.668 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.884 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.880 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.493 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.905 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.668 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.884 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.917 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.735 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.911 total time=   0.5s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.733 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.905 total time=   0.5s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.917 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.725 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.909 total time=   0.5s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.740 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.906 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.916 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.716 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.907 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.734 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.907 total time=   0.5s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.914 total time=   0.6s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.636 total time=   0.6s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.913 total time=   0.7s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.841 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.910 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.914 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.636 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.913 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.841 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.910 total time=   0.5s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.916 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.637 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.914 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.841 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.910 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.909 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.516 total time=   0.5s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.931 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.683 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.909 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.909 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.516 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.931 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.683 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.909 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.909 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.516 total time=   0.5s
# [CV 3/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.931 total time=   0.7s
# [CV 4/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.683 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.909 total time=   0.7s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.924 total time=   0.6s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.683 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.905 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.724 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=2;, score=0.907 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.926 total time=   0.4s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.689 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.913 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.710 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=5;, score=0.916 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.924 total time=   0.4s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.673 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.917 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.697 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=1, min_samples_split=10;, score=0.904 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.931 total time=   0.4s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.601 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.922 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.798 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=2;, score=0.920 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.931 total time=   0.4s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.601 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.922 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.798 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=5;, score=0.920 total time=   0.6s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.927 total time=   0.6s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.603 total time=   1.6s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.915 total time=   0.7s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.790 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=3, min_samples_split=10;, score=0.907 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.887 total time=   0.4s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.490 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.915 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.651 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=2;, score=0.896 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.887 total time=   0.4s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.490 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.915 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.651 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=5;, score=0.896 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.887 total time=   0.4s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.490 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.915 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.651 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=10, min_samples_split=10;, score=0.896 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.945 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.708 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.932 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.742 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=2;, score=0.939 total time=   0.6s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.945 total time=   0.7s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.720 total time=   0.8s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.932 total time=   0.7s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.751 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.939 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.942 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.732 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.933 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.743 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.934 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.942 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.631 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.932 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.845 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=2;, score=0.941 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.942 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.631 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.932 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.845 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=5;, score=0.941 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.941 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.613 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.939 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.849 total time=   0.6s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=3, min_samples_split=10;, score=0.938 total time=   0.8s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.918 total time=   0.7s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.506 total time=   0.7s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.938 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.691 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=2;, score=0.917 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.918 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.506 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.938 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.691 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.917 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.918 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.506 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.938 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.691 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.917 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.965 total time=   0.6s
# [CV 2/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.759 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.951 total time=   0.6s
# [CV 4/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.773 total time=   0.6s
# [CV 5/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.958 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.963 total time=   0.6s
# [CV 2/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.754 total time=   0.7s
# [CV 3/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.952 total time=   0.8s
# [CV 4/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.758 total time=   0.8s
# [CV 5/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=5;, score=0.957 total time=   0.8s
# [CV 1/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.957 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.747 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.954 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.768 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=6, min_samples_leaf=1, min_samples_split=10;, score=0.957 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.957 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.646 total time=   0.6s
# [CV 3/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.954 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.871 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=2;, score=0.957 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.957 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.646 total time=   0.6s
# [CV 3/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.954 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.871 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=5;, score=0.957 total time=   0.6s
# [CV 1/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.952 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.644 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.951 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.859 total time=   0.7s
# [CV 5/5] END max_depth=7, max_features=6, min_samples_leaf=3, min_samples_split=10;, score=0.956 total time=   0.8s
# [CV 1/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.927 total time=   0.8s
# [CV 2/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.534 total time=   0.7s
# [CV 3/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.953 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.698 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=2;, score=0.938 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.927 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.534 total time=   0.6s
# [CV 3/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.953 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.698 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=5;, score=0.938 total time=   0.5s
# [CV 1/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.927 total time=   0.5s
# [CV 2/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.534 total time=   0.5s
# [CV 3/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.953 total time=   0.5s
# [CV 4/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.698 total time=   0.5s
# [CV 5/5] END max_depth=7, max_features=6, min_samples_leaf=10, min_samples_split=10;, score=0.938 total time=   0.5s
# Best parameters :  {'max_depth': 7, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best score :  0.8810420834518464

# %% [markdown]
# It takes 3m 14s to execute

# %%
y_pred4 = gcv_rf.predict(X_test_scaled)

print('R2 score: ',r2_score(y_test,y_pred4))
# Out:
# R2 score:  0.9481274541889839

# %%
Accuracy_Scores.append(r2_score(y_test,y_pred4))

# %%
plt.scatter(y_test, y_pred4,c = 'green')
plt.plot([0, 50], [0, 50], '--k')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title("Actual Value vs Predicted Value :Random Forest")
plt.show()

# %% [markdown]
# ## **Linear regression**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
model_lr=LinearRegression()
params={'fit_intercept': [True]}
gcv_lr = GridSearchCV(estimator=model_lr, param_grid=params,scoring='r2',cv=kfold,verbose=3)
gcv_lr.fit(X_train_scaled,y_train)
print('R2 score: ',gcv_lr.best_score_)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ................fit_intercept=True;, score=0.824 total time=   0.0s
# [CV 2/5] END ................fit_intercept=True;, score=0.851 total time=   0.0s
# [CV 3/5] END ................fit_intercept=True;, score=0.808 total time=   0.0s
# [CV 4/5] END ................fit_intercept=True;, score=0.802 total time=   0.0s
# [CV 5/5] END ................fit_intercept=True;, score=0.748 total time=   0.0s
# R2 score:  0.8066446531639612

# %%
y_pred5 = gcv_lr.predict(X_test_scaled)

print('R2 score: ',r2_score(y_test,y_pred5))
# Out:
# R2 score:  0.8064493663682433

# %%
Accuracy_Scores.append(r2_score(y_test,y_pred5))

# %%
plt.scatter(y_test, y_pred5,c = 'green')
plt.plot([0, 50], [0, 50], '--k')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title("Actual Value vs Predicted Value:Linear Regression")
plt.show()

# %%
# Create a residual plot
residuals = y_test - y_pred5
plt.scatter(y_pred5, residuals)
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# If the relationship between the residuals and the predicted values is non-linear, it may indicate that a linear model is not appropriate for the data. For example, if the residuals follow a U-shaped or inverted U-shaped curve, it may suggest that a polynomial regression model would be more appropriate

# %% [markdown]
# ## **Regularization**

# %% [markdown]
# ### Ridge

# %%
from sklearn.linear_model import Ridge,Lasso,ElasticNet

# %%
model_ridge=Ridge()
params={'alpha':np.arange(0.1,2,0.2)}
gsv_ridge=GridSearchCV(model_ridge, param_grid=params,scoring='r2',cv=kfold,verbose=3)
gsv_ridge.fit(X_train_scaled,y_train)
print('Best params: ',gsv_ridge.best_params_)
print('Best score ',gsv_ridge.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .........................alpha=0.1;, score=0.824 total time=   0.0s
# [CV 2/5] END .........................alpha=0.1;, score=0.851 total time=   0.0s
# [CV 3/5] END .........................alpha=0.1;, score=0.808 total time=   0.0s
# [CV 4/5] END .........................alpha=0.1;, score=0.802 total time=   0.0s
# [CV 5/5] END .........................alpha=0.1;, score=0.748 total time=   0.0s
# [CV 1/5] END .........alpha=0.30000000000000004;, score=0.824 total time=   0.0s
# [CV 2/5] END .........alpha=0.30000000000000004;, score=0.851 total time=   0.0s
# [CV 4/5] END ..........alpha=1.7000000000000004;, score=0.802 total time=   0.0s
# [CV 5/5] END ..........alpha=1.7000000000000004;, score=0.748 total time=   0.0s
# [CV 1/5] END ..........alpha=1.9000000000000004;, score=0.824 total time=   0.0s
# [CV 2/5] END ..........alpha=1.9000000000000004;, score=0.851 total time=   0.0s
# [CV 3/5] END ..........alpha=1.9000000000000004;, score=0.808 total time=   0.0s
# [CV 4/5] END ..........alpha=1.9000000000000004;, score=0.802 total time=   0.0s
# [CV 5/5] END ..........alpha=1.9000000000000004;, score=0.748 total time=   0.0s
# Best params:  {'alpha': 1.9000000000000004}
# Best score  0.8067676164771325

# %%
y_pred6 = gsv_ridge.predict(X_test_scaled)

print('R2 score: ',r2_score(y_test,y_pred6))
# Out:
# R2 score:  0.8064771517025301

# %%
Accuracy_Scores.append(r2_score(y_test,y_pred6))

# %% [markdown]
# ### Lasso

# %%
model_lasso=Lasso()
params={'alpha':np.arange(0.1,2,0.2)}
kfold=KFold(n_splits=5,shuffle=True,random_state=2022)
gsv_lasso=GridSearchCV(model_lasso, param_grid=params,scoring='r2',cv=kfold,verbose=3)
gsv_lasso.fit(X_train_scaled,y_train)
print('Best params: ',gsv_lasso.best_params_)
print('Best score: ',gsv_lasso.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .........................alpha=0.1;, score=0.824 total time=   0.0s
# [CV 2/5] END .........................alpha=0.1;, score=0.850 total time=   0.0s
# [CV 3/5] END .........................alpha=0.1;, score=0.809 total time=   0.0s
# [CV 4/5] END .........................alpha=0.1;, score=0.802 total time=   0.0s
# [CV 5/5] END .........................alpha=0.1;, score=0.749 total time=   0.0s
# [CV 1/5] END .........alpha=0.30000000000000004;, score=0.825 total time=   0.0s
# [CV 2/5] END .........alpha=0.30000000000000004;, score=0.848 total time=   0.0s
# [CV 3/5] END .........alpha=0.30000000000000004;, score=0.810 total time=   0.0s
# [CV 4/5] END .........alpha=0.30000000000000004;, score=0.802 total time=   0.0s
# [CV 5/5] END .........alpha=0.30000000000000004;, score=0.750 total time=   0.0s
# [CV 1/5] END ..........alpha=0.5000000000000001;, score=0.825 total time=   0.0s
# [CV 2/5] END ..........alpha=0.5000000000000001;, score=0.846 total time=   0.0s
# [CV 3/5] END ..........alpha=0.5000000000000001;, score=0.811 total time=   0.0s
# [CV 4/5] END ..........alpha=0.5000000000000001;, score=0.802 total time=   0.0s
# [CV 5/5] END ..........alpha=0.5000000000000001;, score=0.750 total time=   0.0s
# [CV 1/5] END ..........alpha=0.7000000000000001;, score=0.825 total time=   0.0s
# [CV 2/5] END ..........alpha=0.7000000000000001;, score=0.844 total time=   0.0s
# [CV 3/5] END ..........alpha=0.7000000000000001;, score=0.811 total time=   0.0s
# [CV 4/5] END ..........alpha=0.7000000000000001;, score=0.801 total time=   0.0s
# [CV 5/5] END ..........alpha=0.7000000000000001;, score=0.750 total time=   0.0s
# [CV 1/5] END ..........alpha=0.9000000000000001;, score=0.825 total time=   0.0s
# [CV 2/5] END ..........alpha=0.9000000000000001;, score=0.842 total time=   0.0s
# [CV 3/5] END ..........alpha=0.9000000000000001;, score=0.811 total time=   0.0s
# [CV 4/5] END ..........alpha=0.9000000000000001;, score=0.801 total time=   0.0s
# [CV 5/5] END ..........alpha=0.9000000000000001;, score=0.750 total time=   0.0s
# [CV 1/5] END ..........alpha=1.1000000000000003;, score=0.826 total time=   0.0s
# [CV 2/5] END ..........alpha=1.1000000000000003;, score=0.840 total time=   0.0s
# [CV 3/5] END ..........alpha=1.1000000000000003;, score=0.812 total time=   0.0s
# [CV 4/5] END ..........alpha=1.1000000000000003;, score=0.802 total time=   0.0s
# [CV 5/5] END ..........alpha=1.1000000000000003;, score=0.750 total time=   0.0s
# [CV 1/5] END ..........alpha=1.3000000000000003;, score=0.826 total time=   0.0s
# [CV 2/5] END ..........alpha=1.3000000000000003;, score=0.838 total time=   0.0s
# [CV 3/5] END ..........alpha=1.3000000000000003;, score=0.812 total time=   0.0s
# [CV 4/5] END ..........alpha=1.3000000000000003;, score=0.802 total time=   0.0s
# [CV 5/5] END ..........alpha=1.3000000000000003;, score=0.750 total time=   0.0s
# [CV 1/5] END ..........alpha=1.5000000000000004;, score=0.827 total time=   0.0s
# [CV 2/5] END ..........alpha=1.5000000000000004;, score=0.837 total time=   0.0s
# [CV 3/5] END ..........alpha=1.5000000000000004;, score=0.812 total time=   0.0s
# [CV 4/5] END ..........alpha=1.5000000000000004;, score=0.802 total time=   0.0s
# [CV 5/5] END ..........alpha=1.5000000000000004;, score=0.750 total time=   0.0s
# [CV 1/5] END ..........alpha=1.7000000000000004;, score=0.827 total time=   0.0s
# [CV 2/5] END ..........alpha=1.7000000000000004;, score=0.835 total time=   0.0s
# [CV 3/5] END ..........alpha=1.7000000000000004;, score=0.812 total time=   0.0s
# [CV 4/5] END ..........alpha=1.7000000000000004;, score=0.802 total time=   0.0s
# [CV 5/5] END ..........alpha=1.7000000000000004;, score=0.750 total time=   0.0s
# [CV 1/5] END ..........alpha=1.9000000000000004;, score=0.828 total time=   0.0s
# [CV 2/5] END ..........alpha=1.9000000000000004;, score=0.833 total time=   0.0s
# [CV 3/5] END ..........alpha=1.9000000000000004;, score=0.812 total time=   0.0s
# [CV 4/5] END ..........alpha=1.9000000000000004;, score=0.803 total time=   0.0s
# [CV 5/5] END ..........alpha=1.9000000000000004;, score=0.749 total time=   0.0s
# Best params:  {'alpha': 0.30000000000000004}
# Best score:  0.8069592093371641

# %%
y_pred7 = gsv_lasso.predict(X_test_scaled)

print('R2 score: ',r2_score(y_test,y_pred7))
# Out:
# R2 score:  0.8073488211466131

# %%
Accuracy_Scores.append(r2_score(y_test,y_pred7))

# %% [markdown]
# ## **Polynomial**

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ###### **Poly-Ridge with r2 score**

# %%
ridge=Ridge()
poly=PolynomialFeatures()
pipe=Pipeline([('poly',poly),('rdge',ridge)])
params={'rdge__alpha':np.arange(0.1,2,0.1),'poly__degree':[1,2]}
kfold=KFold(n_splits=5,shuffle=True,random_state=2022)
# [CV 4/5] END poly__degree=2, rdge__alpha=1.8000000000000003;, score=0.928 total time=   0.1s
# [CV 5/5] END poly__degree=2, rdge__alpha=1.8000000000000003;, score=0.990 total time=   0.1s
# [CV 1/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=0.119 total time=   0.0s
# [CV 2/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=0.504 total time=   0.0s
# [CV 3/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=0.981 total time=   0.1s
# [CV 4/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=0.928 total time=   0.1s
# [CV 5/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=0.990 total time=   0.1s
# Best ridge params  1.9000000000000001
# Best ridge params : 1
# Best score  0.8067676164771326

# %%
y_pred8 = gsv_red_pol.predict(X_test_scaled)

print('R2 score: ',r2_score(y_test,y_pred8))
# Out:
# R2 score:  0.8064771517025301

# %%
Accuracy_Scores.append(r2_score(y_test,y_pred8))

# %%
best_model = gsv_red_pol.best_estimator_
best_model
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(degree=1)),
#                 ('rdge', Ridge(alpha=1.9000000000000001))])

# %%
'''
import pickle
picklefile = open('/content/sample_data/poly.model', 'wb')
    #pickle the dictionary and write it to file
pickle.dump(best_model, picklefile)
    #close the file
picklefile.close()
'''

# %% [markdown]
# ######**Poly-Ridge with MAE**

# %%
ridge=Ridge()
poly=PolynomialFeatures()
pipe=Pipeline([('poly',poly),('rdge',ridge)])
params={'rdge__alpha':np.arange(0.1,2,0.1),'poly__degree':[1,2]}
kfold=KFold(n_splits=5,shuffle=True,random_state=2022)
gsv_red_pol=GridSearchCV(pipe, param_grid=params,scoring='neg_mean_absolute_error',cv=kfold,verbose=3)
gsv_red_pol.fit(X_train_scaled,y_train)
print('Best ridge params ',gsv_red_pol.best_params_['rdge__alpha'])
print('Best ridge params :',gsv_red_pol.best_params_['poly__degree'])
print('Best score ',gsv_red_pol.best_score_)
# Out:
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# [CV 1/5] END .poly__degree=1, rdge__alpha=0.1;, score=-32.341 total time=   0.0s
# [CV 2/5] END .poly__degree=1, rdge__alpha=0.1;, score=-31.488 total time=   0.0s
# [CV 3/5] END .poly__degree=1, rdge__alpha=0.1;, score=-30.917 total time=   0.0s
# [CV 4/5] END .poly__degree=1, rdge__alpha=0.1;, score=-30.246 total time=   0.0s
# [CV 5/5] END .poly__degree=1, rdge__alpha=0.1;, score=-30.539 total time=   0.0s
# [CV 1/5] END .poly__degree=1, rdge__alpha=0.2;, score=-32.340 total time=   0.0s
# [CV 2/5] END .poly__degree=1, rdge__alpha=0.2;, score=-31.487 total time=   0.0s
# [CV 3/5] END .poly__degree=1, rdge__alpha=0.2;, score=-30.916 total time=   0.0s
# [CV 4/5] END .poly__degree=1, rdge__alpha=0.2;, score=-30.245 total time=   0.0s
# [CV 5/5] END .poly__degree=1, rdge__alpha=0.2;, score=-30.539 total time=   0.0s
# [CV 4/5] END poly__degree=2, rdge__alpha=1.4000000000000001;, score=-5.929 total time=   0.1s
# [CV 5/5] END poly__degree=2, rdge__alpha=1.4000000000000001;, score=-5.419 total time=   0.1s
# [CV 1/5] END poly__degree=2, rdge__alpha=1.5000000000000002;, score=-9.021 total time=   0.0s
# [CV 2/5] END poly__degree=2, rdge__alpha=1.5000000000000002;, score=-10.467 total time=   0.1s
# [CV 3/5] END poly__degree=2, rdge__alpha=1.5000000000000002;, score=-5.869 total time=   0.1s
# [CV 4/5] END poly__degree=2, rdge__alpha=1.5000000000000002;, score=-5.929 total time=   0.1s
# [CV 5/5] END poly__degree=2, rdge__alpha=1.5000000000000002;, score=-5.420 total time=   0.0s
# [CV 1/5] END ..poly__degree=2, rdge__alpha=1.6;, score=-9.014 total time=   0.0s
# [CV 2/5] END .poly__degree=2, rdge__alpha=1.6;, score=-10.462 total time=   0.0s
# [CV 3/5] END ..poly__degree=2, rdge__alpha=1.6;, score=-5.871 total time=   0.1s
# [CV 4/5] END ..poly__degree=2, rdge__alpha=1.6;, score=-5.928 total time=   0.1s
# [CV 5/5] END ..poly__degree=2, rdge__alpha=1.6;, score=-5.421 total time=   0.1s
# [CV 1/5] END poly__degree=2, rdge__alpha=1.7000000000000002;, score=-9.007 total time=   0.1s
# [CV 2/5] END poly__degree=2, rdge__alpha=1.7000000000000002;, score=-10.456 total time=   0.1s
# [CV 3/5] END poly__degree=2, rdge__alpha=1.7000000000000002;, score=-5.873 total time=   0.1s
# [CV 4/5] END poly__degree=2, rdge__alpha=1.7000000000000002;, score=-5.927 total time=   0.1s
# [CV 5/5] END poly__degree=2, rdge__alpha=1.7000000000000002;, score=-5.421 total time=   0.1s
# [CV 1/5] END poly__degree=2, rdge__alpha=1.8000000000000003;, score=-9.000 total time=   0.0s
# [CV 2/5] END poly__degree=2, rdge__alpha=1.8000000000000003;, score=-10.450 total time=   0.0s
# [CV 3/5] END poly__degree=2, rdge__alpha=1.8000000000000003;, score=-5.875 total time=   0.0s
# [CV 4/5] END poly__degree=2, rdge__alpha=1.8000000000000003;, score=-5.926 total time=   0.0s
# [CV 5/5] END poly__degree=2, rdge__alpha=1.8000000000000003;, score=-5.422 total time=   0.1s
# [CV 1/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=-8.993 total time=   0.1s
# [CV 2/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=-10.445 total time=   0.1s
# [CV 3/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=-5.876 total time=   0.1s
# [CV 4/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=-5.924 total time=   0.1s
# [CV 5/5] END poly__degree=2, rdge__alpha=1.9000000000000001;, score=-5.422 total time=   0.1s
# Best ridge params  1.9000000000000001
# Best ridge params : 2
# Best score  -7.332259920191402

# %%
y_pred9 = gsv_red_pol.predict(X_test_scaled)

print('MAE score: ',mean_absolute_error(y_test,y_pred9))
# Out:
# MAE score:  6.188786093066209

# %% [markdown]
# ####**Poly-Lasso with r2 score**

# %%
lasso=Lasso()
poly=PolynomialFeatures()
pipe_pol_lso=Pipeline([('poly',poly),('lso',lasso)])
params={'lso__alpha':np.arange(0.1,1,0.2),'poly__degree':[2,3]}
kfold=KFold(n_splits=3,shuffle=True,random_state=2022)
gsv_pol_lso=GridSearchCV(pipe_pol_lso, param_grid=params,scoring='r2',cv=kfold,verbose=3)
gsv_pol_lso.fit(X_train_scaled,y_train)
print('Best lasso params ',gsv_pol_lso.best_params_['lso__alpha'])
print('Best Poly params:',gsv_pol_lso.best_params_['poly__degree'])
print(' best score ',gsv_pol_lso.best_score_)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END ....lso__alpha=0.1, poly__degree=2;, score=0.887 total time=   0.5s
# [CV 2/3] END ....lso__alpha=0.1, poly__degree=2;, score=0.986 total time=   0.6s
# [CV 3/3] END ....lso__alpha=0.1, poly__degree=2;, score=0.938 total time=   0.6s
# [CV 1/3] END ...lso__alpha=0.1, poly__degree=3;, score=-0.305 total time=   8.2s
# [CV 2/3] END ....lso__alpha=0.1, poly__degree=3;, score=0.987 total time=  13.8s
# [CV 3/3] END ....lso__alpha=0.1, poly__degree=3;, score=0.955 total time=   7.4s
# [CV 1/3] END lso__alpha=0.30000000000000004, poly__degree=2;, score=0.926 total time=   0.2s
# [CV 2/3] END lso__alpha=0.30000000000000004, poly__degree=2;, score=0.986 total time=   0.4s
# [CV 3/3] END lso__alpha=0.30000000000000004, poly__degree=2;, score=0.947 total time=   0.4s
# [CV 1/3] END lso__alpha=0.30000000000000004, poly__degree=3;, score=0.701 total time=   8.6s
# [CV 2/3] END lso__alpha=0.30000000000000004, poly__degree=3;, score=0.986 total time=   4.8s
# [CV 3/3] END lso__alpha=0.30000000000000004, poly__degree=3;, score=0.960 total time=   6.1s
# [CV 1/3] END lso__alpha=0.5000000000000001, poly__degree=2;, score=0.909 total time=   0.3s
# [CV 2/3] END lso__alpha=0.5000000000000001, poly__degree=2;, score=0.986 total time=   0.5s
# [CV 3/3] END lso__alpha=0.5000000000000001, poly__degree=2;, score=0.950 total time=   0.4s
# [CV 1/3] END lso__alpha=0.5000000000000001, poly__degree=3;, score=0.903 total time=   8.4s
# [CV 2/3] END lso__alpha=0.5000000000000001, poly__degree=3;, score=0.985 total time=   4.8s
# [CV 3/3] END lso__alpha=0.5000000000000001, poly__degree=3;, score=0.963 total time=   5.4s
# [CV 1/3] END lso__alpha=0.7000000000000001, poly__degree=2;, score=0.879 total time=   0.1s
# [CV 2/3] END lso__alpha=0.7000000000000001, poly__degree=2;, score=0.986 total time=   0.5s
# [CV 3/3] END lso__alpha=0.7000000000000001, poly__degree=2;, score=0.952 total time=   0.3s
# [CV 1/3] END lso__alpha=0.7000000000000001, poly__degree=3;, score=0.946 total time=   8.6s
# [CV 2/3] END lso__alpha=0.7000000000000001, poly__degree=3;, score=0.985 total time=   7.4s
# [CV 3/3] END lso__alpha=0.7000000000000001, poly__degree=3;, score=0.960 total time=   6.7s
# [CV 1/3] END lso__alpha=0.9000000000000001, poly__degree=2;, score=0.856 total time=   0.1s
# [CV 2/3] END lso__alpha=0.9000000000000001, poly__degree=2;, score=0.986 total time=   0.4s
# [CV 3/3] END lso__alpha=0.9000000000000001, poly__degree=2;, score=0.951 total time=   0.3s
# [CV 1/3] END lso__alpha=0.9000000000000001, poly__degree=3;, score=0.953 total time=   6.2s
# [CV 2/3] END lso__alpha=0.9000000000000001, poly__degree=3;, score=0.985 total time=   6.9s
# [CV 3/3] END lso__alpha=0.9000000000000001, poly__degree=3;, score=0.963 total time=   8.0s
# Best lasso params  0.9000000000000001
# Best Poly params: 3
#  best score  0.9668643608090859

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge,Lasso,ElasticNet

# %%
y_pred10 = gsv_pol_lso.predict(X_test_scaled)

print('R2 score: ',r2_score(y_test,y_pred10))
# Out:
# R2 score:  0.9881120989232671

# %%
Accuracy_Scores.append(r2_score(y_test,y_pred10))

# %% [markdown]
# ####**Poly-Lasso with MAE**

# %%
lasso=Lasso()
poly=PolynomialFeatures()
pipe_pol_lso_mae=Pipeline([('poly',poly),('lso',lasso)])
params={'lso__alpha':np.arange(0.1,2,0.1),'poly__degree':[1,2,3]}
kfold=KFold(n_splits=5,shuffle=True,random_state=2022)
gsv_pol_lso_mae=GridSearchCV(pipe_pol_lso_mae, param_grid=params,scoring='neg_mean_absolute_error',cv=kfold,verbose=3)
gsv_pol_lso_mae.fit(X_train_scaled,y_train)
print('Best lasso params ',gsv_pol_lso_mae.best_params_['lso__alpha'])
print('Best Poly params:',gsv_pol_lso_mae.best_params_['poly__degree'])
print(' best score ',gsv_pol_lso_mae.best_score_)
# Out:
# Fitting 5 folds for each of 57 candidates, totalling 285 fits
# [CV 1/5] END ..lso__alpha=0.1, poly__degree=1;, score=-32.245 total time=   0.0s
# [CV 2/5] END ..lso__alpha=0.1, poly__degree=1;, score=-31.433 total time=   0.0s
# [CV 3/5] END ..lso__alpha=0.1, poly__degree=1;, score=-30.821 total time=   0.0s
# [CV 4/5] END ..lso__alpha=0.1, poly__degree=1;, score=-30.201 total time=   0.0s
# [CV 5/5] END ..lso__alpha=0.1, poly__degree=1;, score=-30.423 total time=   0.0s
# [CV 1/5] END ...lso__alpha=0.1, poly__degree=2;, score=-5.511 total time=   0.8s
# [CV 2/5] END ...lso__alpha=0.1, poly__degree=2;, score=-8.725 total time=   0.4s
# [CV 3/5] END ...lso__alpha=0.1, poly__degree=2;, score=-5.404 total time=   0.7s
# [CV 4/5] END ...lso__alpha=0.1, poly__degree=2;, score=-5.333 total time=   0.8s
# [CV 5/5] END ...lso__alpha=0.1, poly__degree=2;, score=-5.180 total time=   0.8s
# [CV 1/5] END ...lso__alpha=0.1, poly__degree=3;, score=-4.640 total time=  11.5s
# [CV 2/5] END ..lso__alpha=0.1, poly__degree=3;, score=-14.525 total time=  17.4s
# [CV 3/5] END ...lso__alpha=0.1, poly__degree=3;, score=-4.694 total time=   9.6s
# [CV 4/5] END ...lso__alpha=0.1, poly__degree=3;, score=-4.835 total time=  10.7s
# [CV 1/5] END ..lso__alpha=0.4, poly__degree=1;, score=-32.087 total time=   0.0s
# [CV 2/5] END ..lso__alpha=0.4, poly__degree=1;, score=-31.280 total time=   0.0s
# [CV 3/5] END ..lso__alpha=0.4, poly__degree=1;, score=-30.617 total time=   0.0s
# [CV 4/5] END ..lso__alpha=0.4, poly__degree=1;, score=-30.110 total time=   0.0s
# [CV 5/5] END ..lso__alpha=0.4, poly__degree=1;, score=-30.230 total time=   0.0s
# [CV 1/5] END ...lso__alpha=0.4, poly__degree=2;, score=-5.311 total time=   0.5s
# [CV 2/5] END ...lso__alpha=0.4, poly__degree=2;, score=-7.850 total time=   0.3s
# [CV 3/5] END ...lso__alpha=0.4, poly__degree=2;, score=-5.490 total time=   0.4s
# [CV 4/5] END ...lso__alpha=0.4, poly__degree=2;, score=-4.961 total time=   0.5s
# [CV 5/5] END ...lso__alpha=0.4, poly__degree=2;, score=-5.062 total time=   0.4s
# [CV 1/5] END ...lso__alpha=0.4, poly__degree=3;, score=-4.712 total time=   6.2s
# [CV 2/5] END ..lso__alpha=0.4, poly__degree=3;, score=-10.173 total time=  11.0s
# [CV 3/5] END ...lso__alpha=0.4, poly__degree=3;, score=-4.789 total time=   6.3s
# [CV 4/5] END ...lso__alpha=0.4, poly__degree=3;, score=-4.984 total time=   6.4s
# [CV 5/5] END ...lso__alpha=0.4, poly__degree=3;, score=-4.808 total time=   6.5s
# [CV 1/5] END ..lso__alpha=0.5, poly__degree=1;, score=-32.070 total time=   0.0s
# [CV 2/5] END ..lso__alpha=0.5, poly__degree=1;, score=-31.237 total time=   0.0s
# [CV 3/5] END ..lso__alpha=0.5, poly__degree=1;, score=-30.562 total time=   0.0s
# [CV 4/5] END ..lso__alpha=0.5, poly__degree=1;, score=-30.091 total time=   0.0s
# [CV 5/5] END ..lso__alpha=0.5, poly__degree=1;, score=-30.206 total time=   0.0s
# [CV 1/5] END ...lso__alpha=0.5, poly__degree=2;, score=-5.315 total time=   0.5s
# [CV 2/5] END ...lso__alpha=0.5, poly__degree=2;, score=-7.796 total time=   0.2s
# [CV 3/5] END ...lso__alpha=0.5, poly__degree=2;, score=-5.562 total time=   0.5s
# [CV 4/5] END ...lso__alpha=0.5, poly__degree=2;, score=-4.970 total time=   0.4s
# [CV 5/5] END ...lso__alpha=0.5, poly__degree=2;, score=-5.076 total time=   0.4s
# [CV 1/5] END ...lso__alpha=0.5, poly__degree=3;, score=-4.801 total time=   8.0s
# [CV 2/5] END ...lso__alpha=0.5, poly__degree=3;, score=-9.110 total time=  10.6s
# [CV 3/5] END ...lso__alpha=0.5, poly__degree=3;, score=-4.941 total time=   6.5s
# [CV 4/5] END ...lso__alpha=0.5, poly__degree=3;, score=-5.156 total time=   8.4s
# [CV 5/5] END ...lso__alpha=0.5, poly__degree=3;, score=-4.882 total time=   7.0s
# [CV 1/5] END ..lso__alpha=0.6, poly__degree=1;, score=-32.066 total time=   0.0s
# [CV 2/5] END ..lso__alpha=0.6, poly__degree=1;, score=-31.199 total time=   0.0s
# [CV 4/5] END ..lso__alpha=0.8, poly__degree=1;, score=-30.064 total time=   0.0s
# [CV 5/5] END ..lso__alpha=0.8, poly__degree=1;, score=-30.146 total time=   0.0s
# [CV 1/5] END ...lso__alpha=0.8, poly__degree=2;, score=-5.437 total time=   0.8s
# [CV 2/5] END ...lso__alpha=0.8, poly__degree=2;, score=-7.926 total time=   0.3s
# [CV 3/5] END ...lso__alpha=0.8, poly__degree=2;, score=-5.772 total time=   0.9s
# [CV 4/5] END ...lso__alpha=0.8, poly__degree=2;, score=-5.074 total time=   0.4s
# [CV 5/5] END ...lso__alpha=0.8, poly__degree=2;, score=-5.208 total time=   0.6s
# [CV 1/5] END ...lso__alpha=0.8, poly__degree=3;, score=-5.110 total time=   8.4s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-9cd8d36a2fd3> in <module>
#       5 kfold=KFold(n_splits=5,shuffle=True,random_state=2022)
#       6 gsv_pol_lso_mae=GridSearchCV(pipe_pol_lso_mae, param_grid=params,scoring='neg_mean_absolute_error',cv=kfold,verbose=3)
# ----> 7 gsv_pol_lso_mae.fit(X_train_scaled,y_train)
#       8 print('Best lasso params ',gsv_pol_lso_mae.best_params_['lso__alpha'])
#       9 print('Best Poly params:',gsv_pol_lso_mae.best_params_['poly__degree'])
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1086                 self._iterating = self._original_iterator is not None
#    1087
# -> 1088             while self.dispatch_one_batch(iterator):
#    1089                 pass
#    1090
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.9/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.9/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# /usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     403             if self._final_estimator != "passthrough":
#     404                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     406
#     407         return self
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_coordinate_descent.py in fit(self, X, y, sample_weight, check_input)
#    1002             else:
#    1003                 this_Xy = None
# -> 1004             _, this_coef, this_dual_gap, this_iter = self.path(
#    1005                 X,
#    1006                 y[:, k],
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_coordinate_descent.py in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     629             )
#     630         elif precompute is False:
# --> 631             model = cd_fast.enet_coordinate_descent(
#     632                 coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
#     633             )
#
# sklearn/linear_model/_cd_fast.pyx in sklearn.linear_model._cd_fast.enet_coordinate_descent()
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/getlimits.py in __new__(cls, dtype)
#     456
#     457     def __new__(cls, dtype):
# --> 458         try:
#     459             dtype = numeric.dtype(dtype)
#     460         except TypeError:
#
# KeyboardInterrupt:

# %% [markdown]
# It takes 14min 20 sec i.e almost 15 min to execute

# %%
y_pred11 = gsv_pol_lso_mae.predict(X_test_scaled)

print('MAE score: ',mean_absolute_error(y_test,y_pred11))
# Out:
# MAE score:  5.505265568879492

# %%
Accuracy_Scores
# Out:
# [0.8450578330169121,
#  0.7741136889359705,
#  0.9331231712457421,
#  0.9481274541889839,
#  0.8064493663682433,
#  0.8064771517025301,
#  0.8073488211466131,
#  0.8064771517025301,
#  0.9881120989232671]

# %% [markdown]
# #6.Comparison Graph of Accuracy Scores of each algorithm

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(16, 5),facecolor = 'skyblue')
model=['KNN','SVR','XGBRegressor','Random Forest','Linear regression','Ridge','Lasso','Poly-Ridge','Poly-Lasso']
c = ['y','r','purple','cyan','orange','pink','b','indigo','g']
plt.bar(model,Accuracy_Scores,color = c)
plt.title('Accuracy R2 Scores of each model')
plt.xlabel('Models')
plt.ylabel('Accuracy Scores(r2)')
plt.show()
